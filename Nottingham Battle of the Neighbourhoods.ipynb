# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 1)
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
#     * [Crime in Nottingham](#Crime_Nottm)
#     * [Venues in Nottingham](#Venue_Nottm)
#     * [LSOA Revisited](#LSOA)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# Nottingham is a medium sized city in the East Midland of the England in the UK.   It has a thriving and lively nightlife with a wide and eclectic range of restaurants, cafes, bars and clubs catering to many different categories of people including the student of two universities.  The City is a chosen weekend destination for groups of young people from all over the UK.
#
# Nottingham also has, like many cities in the UK, crime issues, with parts of the city and its environs exceeding the national crime rate by in excess of 100% (within particular crime categories - see https://www.plumplot.co.uk/Nottingham-violent-crime-statistics.html).
#
# The requirement in this case is to assess the optimum placement of restaurants / cafes / bars in areas that are more popular for dining and there is regular footfall and to take account of the crime statistics for that location and there the safety of customers and property of the given business.  The data search should happen for the boroughs of Nottingham and the connected urban boroughs of Broxtowe, Gedling and Rushcliffe.  It is intended that this data should be used by people who are looking to set up a hospitality busiess within the environs of Nottingham to help them decide whcih factors that they will take into account when choosing restaurant location.

# %% [markdown]
# ## Data <a name="data"></a>
# Based on the definition of the problem, we need to breakdown the research into two separate areas - the crime in a particular area and corresponding restaurant activity in that area.

# %% [markdown]
# ## Crime in Nottingam 2019 <a name="Crime_Nottm"></a>

# %% [markdown]
# Based on the definition of the problem, we need to know the following type of information:-
# *	The number of crimes in a given location
# *	The type of crimes in a given location
# *	The frequency of crimes in a given location.
#
# Data about recorded crimes is held for each Police force in the UK in the Police Data Portal (https://data.police.uk/).  The portal does provide an API to access the data but this will only provide records for the specified month – if no month is specified then data for the previous month is returned.  Since it is part of the scope of this analysis to include a view on the frequency of the crimes then we need to collect data on more than one time period - preferably over a year.
#
# The Police Data portal allows the selection and download of CSV files – selecting the Police Force and the Month that the crime was recorded in - to download.  The data is downloaded in a zip file containing CSV files in separate directories for each selected month.  Since this data cannot be accessed directly from Python, it was decided to download locally data relevant to the greater Nottingham area for the whole of the year 2019 and hold this in DB2 for subsequent querying using python. It was decided that only crime data should be downloaded, and that outcomes and stop-and-search data would not have any significance in the analysis the crime rate.
#
# The format of the CSV is described in the in the table below.  From examination of this data it is clear that various fields will not be required in the analysis and as such the last column of the table shows which of the fields should be retained or discarded for use in this analysis.
#
#
# | Field           | Meaning                                                  | Discard   |
# |:--------------- |:---------------------------------------------------------|:----------|
# | Crime Id        | Identifier for the individual crime                      | Discard   |
# | Month           | The Year and Month that the crime was reported in        | Retain    |
# | Reported By     | The force that provided the data about the crime.        | Retain    |
# | Falls within    | Currently the force that provided the data about the crime | Discard      |
# | Location | Rough description of the location of the Crime | Discard |
# | Latitiude & Longitude | The anonymised coordinates of the crime. | Retain  |
# | LSOA Code & Name | References to the Lower Layer Super Output Area that the anonymised point falls into (see later) | Retain   |
# | Crime Type    | Categorisation of the crime                           | Retain     |
# | Last Outcome    |  reference to whichever of the outcomes associated with the crime occurred most recently.| Discard   |
# | Context   | A field provided for forces to provide additional human-readable data about individual crimes. | Discard   |
#
# Fields that are not to be retained are generally those used to identify the individual crime and as such are of no use in the aggregation of the crime information.
# The LSOA information is a uses a standard method (according the UK Office of National Statistics) of grouping the crimes into a recognised geographical location.   In particular the naming format allows human readable information regarding which Borough the crime was committed in.
#
# ## LSOA and choice of Geographic Grouping
# As has been noted each crime has been recorded with the Lower Layer Super Output Area (LSOA) which is a UK standard format for statistical reporting – further information can be found [here](https://geoportal.statistics.gov.uk/datasets/lower-layer-super-output-areas-december-2011-population-weighted-centroids?geometry=-1.607%2C52.888%2C-0.564%2C53.032) .  As an area for geographic grouping the LSOA is somewhat small and as such a larger area geographical grouping is required.
#
#
# ## Records to be Discarded
# Given that the selection ctiteria are for the Month and Police force, the downloaded CSV files contain data regarding crimes committed outside the Greater Nottingham area.  In this case it was decided that records with LSOA indicating that the crime was committed outside of the urban boroughs in or contiguous to Nottingham (Nottingham, Broxtowe, Gedling and Rushcliffe) should be discarded from DB2 in order to cut down on Storage requirements.
#
# Below is a first look at the raw crime data held in DB2:

# %%
import ibm_db
import ibm_db_dbi
import pandas as pd
import numpy as np

# %% [markdown]
# DB2 Service Credentials

# %%
#Replace the placeholder values with the actuals for Db2 Service Credentials
dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "BLUDB"            # e.g. "BLUDB"
dsn_hostname = "dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net"            # e.g.: "dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net"
dsn_port = "50000"                    # e.g. "50000" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"
dsn_uid = "ctz66893"                 # e.g. "abc12345"
dsn_pwd = "bts-x39p7p8fwlm0"

# %%
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd)

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  BLUDB as user:  ctz66893 on host:  dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net

# %%
#connection for pandas
pconn = ibm_db_dbi.Connection(conn)

#query statement to retrieve all rows in in the Crime Table, with the MSOA code and object type assigned
selectQuery = "select* from NOTTINGHAM_CRIME_2019"

#retrieve the query results into a pandas dataframe
NOTTM_CRIMEdf = pd.read_sql(selectQuery, pconn)

#print just the LNAME for first row in the pandas data frame
NOTTM_CRIMEdf.head()
# Out:
#      MONTH             REPORTED_BY  LONGITUDE   LATITUDE  \
# 0  2019-01  Nottinghamshire Police  -1.320816  53.032832
# 1  2019-01  Nottinghamshire Police  -1.312767  53.043870
# 2  2019-01  Nottinghamshire Police  -1.309872  53.040248
# 3  2019-01  Nottinghamshire Police  -1.309787  53.032463
# 4  2019-01  Nottinghamshire Police  -1.317157  53.044533
#
#                             LOCATION  LSOA_CODE      LSOA_NAME  \
# 0             On or near Stoney Lane  E01028092  Broxtowe 001A
# 1              On or near Broad Lane  E01028092  Broxtowe 001A
# 2  On or near Sports/Recreation Area  E01028092  Broxtowe 001A
# 3          On or near Mansfield Road  E01028092  Broxtowe 001A
# 4         On or near Whitehead Drive  E01028093  Broxtowe 001B
#
#                      CRIME_TYPE  \
# 0     Criminal damage and arson
# 1                  Public order
# 2  Violence and sexual offences
# 3  Violence and sexual offences
# 4                 Vehicle crime
#
#                            LAST_OUTCOME_CATEGORY CONTEXT
# 0  Investigation complete; no suspect identified    None
# 1                    Unable to prosecute suspect    None
# 2  Investigation complete; no suspect identified    None
# 3  Investigation complete; no suspect identified    None
# 4  Investigation complete; no suspect identified    None

# %% [markdown]
# Examination of the number of Unique entries for LSOA locations where crimes have occured . . .

# %%
Nottm_LSOA_Unique = NOTTM_CRIMEdf['LSOA_CODE'].unique()
Nottm_LSOA_Unique.shape
# Out:
# (438,)

# %% [markdown]
#  . . . shows that there are 438 different areas, which is too much for this analysis.  However, further examination of the UK Office for National Statistics website shows that there is a higher level grouping for geographical areas - MSOAs - Middle Layer Super Output Areas which hold multiple LSOAs - see this [link](https://geoportal.statistics.gov.uk/datasets/middle-layer-super-output-areas-december-2011-population-weighted-centroids?geometry=-1.700%2C52.878%2C-0.657%2C53.023).  The ONS provides a link from the LSOA to the MSOA which can also be loaded in to DB2 and using SQL Joins this can be incorporated into a Nottinham Crime dataframe for 2019. The data loaded here is the link from the LSOA to the MSOA plus further data about the MSOA itself, which may be useful (but see later).

# %%
#query statement to retrieve all rows in in the Crime Table, with the MSOA code and object type assigned
selectQuery = "select NC.MONTH, NC.REPORTED_BY, NC.LONGITUDE, NC.LATITUDE, NC.LOCATION, NC.LSOA_CODE, NC.LSOA_NAME, NC.CRIME_TYPE, NC.LAST_OUTCOME_CATEGORY,\
MS.MSOA01CD, MS.MSOA01NM, MM.objectid \
from NOTTINGHAM_CRIME_2019 as NC join MSOA_LINK as MS on NC.LSOA_CODE = MS.LSOA01CD \
join MSOA_MASTER as MM on MS.MSOA01CD = MM.MSOA11CD"

#retrieve the query results into a pandas dataframe
NOTTM_MSOA_CRIMEdf = pd.read_sql(selectQuery, pconn)

#print just the LNAME for first row in the pandas data frame
NOTTM_MSOA_CRIMEdf.head()
# Out:
#      MONTH             REPORTED_BY  LONGITUDE   LATITUDE  \
# 0  2019-01  Nottinghamshire Police  -1.303870  53.017443
# 1  2019-01  Nottinghamshire Police  -1.320816  53.032832
# 2  2019-01  Nottinghamshire Police  -1.312767  53.043870
# 3  2019-01  Nottinghamshire Police  -1.309872  53.040248
# 4  2019-01  Nottinghamshire Police  -1.309787  53.032463
#
#                             LOCATION  LSOA_CODE      LSOA_NAME  \
# 0             On or near Supermarket  E01028112  Broxtowe 002C
# 1             On or near Stoney Lane  E01028092  Broxtowe 001A
# 2              On or near Broad Lane  E01028092  Broxtowe 001A
# 3  On or near Sports/Recreation Area  E01028092  Broxtowe 001A
# 4          On or near Mansfield Road  E01028092  Broxtowe 001A
#
#                      CRIME_TYPE  \
# 0                  Public order
# 1     Criminal damage and arson
# 2                  Public order
# 3  Violence and sexual offences
# 4  Violence and sexual offences
#
#                            LAST_OUTCOME_CATEGORY   MSOA01CD      MSOA01NM  \
# 0                    Unable to prosecute suspect  E02005851  Broxtowe 002
# 1  Investigation complete; no suspect identified  E02005850  Broxtowe 001
# 2                    Unable to prosecute suspect  E02005850  Broxtowe 001
# 3  Investigation complete; no suspect identified  E02005850  Broxtowe 001
# 4  Investigation complete; no suspect identified  E02005850  Broxtowe 001
#
#    OBJECTID
# 0      2405
# 1      2404
# 2      2404
# 3      2404
# 4      2404

# %% [markdown]
# Looking at the Number of unique MSOA entries for the above data frame . . .

# %% [markdown]
# As can be seen there are thirteen different categories of Crime recorded by the Police for Nottingham in 2019.  Since the scope of the problem is to investigate the potential impact on a resaurant's property or its customers.  Reveiwing the categories, it is understood that all of the categories should be included since all have the potential to harm property or disuade customers from attending the location.
#
# We can also reveiw the number of crimes by category per month

# %%
Nottm_MSOA_Unique = NOTTM_MSOA_CRIMEdf['MSOA01NM'].unique()
Nottm_MSOA_Unique.shape
# Out:
# (76,)

# %% [markdown]
#  . . . gives a number of 76 which, across the 4 boroughs for Urban Nottingham is more manageable.  This means we can use different Variations of the SQL above to put together different data frames to look at the 2019 crime data in different ways.  The first thing that we should look at is the differnt categoroes of crime that were committed in Nottingham in 2019.

# %%
#query statement to retrieve number of crimes Crime Type
selectQuery = "select CRIME_TYPE, count(*) from NOTTINGHAM_CRIME_2019 group by CRIME_TYPE"

#retrieve the query results into a pandas dataframe
NOTTM_CRIME_TYPE_df = pd.read_sql(selectQuery, pconn)


NOTTM_CRIME_TYPE_df.rename (columns = {'2':'Number Crimes'}, inplace = True)
#print just the LNAME for first row in the pandas data frame
NOTTM_CRIME_TYPE_df
# Out:
#                       CRIME_TYPE  Number Crimes
# 0          Anti-social behaviour        19134.0
# 1                  Bicycle theft         1435.0
# 2                       Burglary         4302.0
# 3      Criminal damage and arson         6594.0
# 4                          Drugs         3640.0
# 5                    Other crime         1718.0
# 6                    Other theft         5926.0
# 7          Possession of weapons          814.0
# 8                   Public order         4580.0
# 9                        Robbery          841.0
# 10                   Shoplifting         6306.0
# 11         Theft from the person         1624.0
# 12                 Vehicle crime         4830.0
# 13  Violence and sexual offences        21243.0

# %%
#query statement to retrieve number of crimes  by Crime Type and Month
selectQuery = "select CRIME_TYPE, MONTH, count(*) as COUNT from NOTTINGHAM_CRIME_2019 group by CRIME_TYPE, MONTH"

#retrieve the query results into a pandas dataframe
NOTTM_CRIME_MONTHdf = pd.read_sql(selectQuery, pconn)

NOTTM_CRIME_MONTHdf.rename (columns = {'6':'Number Crimes'}, inplace = True)
NOTTM_CRIME_MONTHdf.head()

#print just the LNAME for first row in the pandas data frame
NOTTM_CRIME_MONTHdf.head()
# Out:
#                   CRIME_TYPE    MONTH   COUNT
# 0      Anti-social behaviour  2019-01  1303.0
# 1              Bicycle theft  2019-01   103.0
# 2                   Burglary  2019-01   436.0
# 3  Criminal damage and arson  2019-01   546.0
# 4                      Drugs  2019-01   286.0

# %% [markdown]
# Pivot the data to give an improved table of crimes by type per month.

# %%
NOTTM_CRIME_MONTH = NOTTM_CRIME_MONTHdf.pivot(index='CRIME_TYPE',columns='MONTH', values='COUNT')
NOTTM_CRIME_MONTH
# Out:
# MONTH                         2019-01  2019-02  2019-03  2019-04  2019-05  \
# CRIME_TYPE
# Anti-social behaviour          1303.0   1323.0   1541.0   1636.0   1768.0
# Bicycle theft                   103.0     77.0    118.0    119.0    138.0
# Burglary                        436.0    341.0    320.0    344.0    323.0
# Criminal damage and arson       546.0    585.0    534.0    585.0    595.0
# Drugs                           286.0    300.0    308.0    250.0    358.0
# Other crime                     146.0    129.0    130.0    136.0    157.0
# Other theft                     497.0    481.0    542.0    490.0    453.0
# Possession of weapons            76.0     69.0     78.0     71.0     82.0
# Public order                    339.0    336.0    374.0    398.0    439.0
# Robbery                          68.0     73.0     69.0     66.0     80.0
# Shoplifting                     529.0    542.0    619.0    525.0    520.0
# Theft from the person           197.0    258.0    140.0    108.0     73.0
# Vehicle crime                   438.0    388.0    373.0    421.0    392.0
# Violence and sexual offences   1699.0   1581.0   1943.0   1747.0   1878.0
#
# MONTH                         2019-06  2019-07  2019-08  2019-09  2019-10  \
# CRIME_TYPE
# Anti-social behaviour          1701.0   2027.0   1809.0   1573.0   1768.0
# Bicycle theft                   138.0    134.0    112.0    159.0    131.0
# Burglary                        374.0    339.0    295.0    347.0    473.0
# Criminal damage and arson       508.0    617.0    534.0    522.0    577.0
# Drugs                           296.0    304.0    316.0    318.0    326.0
# Other crime                     139.0    151.0    160.0    151.0    160.0
# Other theft                     522.0    592.0    457.0    482.0    494.0
# Possession of weapons            56.0     58.0     58.0     72.0     80.0
# Public order                    421.0    417.0    414.0    354.0    370.0
# Robbery                          61.0     72.0     70.0     57.0     88.0
# Shoplifting                     575.0    571.0    486.0    470.0    494.0
# Theft from the person           106.0     99.0     80.0     83.0    151.0
# Vehicle crime                   380.0    378.0    388.0    408.0    416.0
# Violence and sexual offences   1838.0   1926.0   1776.0   1653.0   1745.0
#
# MONTH                         2019-11  2019-12
# CRIME_TYPE
# Anti-social behaviour          1405.0   1280.0
# Bicycle theft                   113.0     93.0
# Burglary                        401.0    309.0
# Criminal damage and arson       490.0    501.0
# Drugs                           282.0    296.0
# Other crime                     146.0    113.0
# Other theft                     434.0    482.0
# Possession of weapons            67.0     47.0
# Public order                    377.0    341.0
# Robbery                          65.0     72.0
# Shoplifting                     561.0    414.0
# Theft from the person           154.0    175.0
# Vehicle crime                   460.0    388.0
# Violence and sexual offences   1778.0   1679.0

# %% [markdown]
# A Total can be added to the end of this dataframe.

# %%
NOTTM_CRIME_MONTH['Total'] = NOTTM_CRIME_MONTH.sum(axis=1)
NOTTM_CRIME_MONTH
# Out:
# MONTH                         2019-01  2019-02  2019-03  2019-04  2019-05  \
# CRIME_TYPE
# Anti-social behaviour          1303.0   1323.0   1541.0   1636.0   1768.0
# Bicycle theft                   103.0     77.0    118.0    119.0    138.0
# Burglary                        436.0    341.0    320.0    344.0    323.0
# Criminal damage and arson       546.0    585.0    534.0    585.0    595.0
# Drugs                           286.0    300.0    308.0    250.0    358.0
# Other crime                     146.0    129.0    130.0    136.0    157.0
# Other theft                     497.0    481.0    542.0    490.0    453.0
# Possession of weapons            76.0     69.0     78.0     71.0     82.0
# Public order                    339.0    336.0    374.0    398.0    439.0
# Robbery                          68.0     73.0     69.0     66.0     80.0
# Shoplifting                     529.0    542.0    619.0    525.0    520.0
# Theft from the person           197.0    258.0    140.0    108.0     73.0
# Vehicle crime                   438.0    388.0    373.0    421.0    392.0
# Violence and sexual offences   1699.0   1581.0   1943.0   1747.0   1878.0
#
# MONTH                         2019-06  2019-07  2019-08  2019-09  2019-10  \
# CRIME_TYPE
# Anti-social behaviour          1701.0   2027.0   1809.0   1573.0   1768.0
# Bicycle theft                   138.0    134.0    112.0    159.0    131.0
# Burglary                        374.0    339.0    295.0    347.0    473.0
# Criminal damage and arson       508.0    617.0    534.0    522.0    577.0
# Drugs                           296.0    304.0    316.0    318.0    326.0
# Other crime                     139.0    151.0    160.0    151.0    160.0
# Other theft                     522.0    592.0    457.0    482.0    494.0
# Possession of weapons            56.0     58.0     58.0     72.0     80.0
# Public order                    421.0    417.0    414.0    354.0    370.0
# Robbery                          61.0     72.0     70.0     57.0     88.0
# Shoplifting                     575.0    571.0    486.0    470.0    494.0
# Theft from the person           106.0     99.0     80.0     83.0    151.0
# Vehicle crime                   380.0    378.0    388.0    408.0    416.0
# Violence and sexual offences   1838.0   1926.0   1776.0   1653.0   1745.0
#
# MONTH                         2019-11  2019-12    Total
# CRIME_TYPE
# Anti-social behaviour          1405.0   1280.0  19134.0
# Bicycle theft                   113.0     93.0   1435.0
# Burglary                        401.0    309.0   4302.0
# Criminal damage and arson       490.0    501.0   6594.0
# Drugs                           282.0    296.0   3640.0
# Other crime                     146.0    113.0   1718.0
# Other theft                     434.0    482.0   5926.0
# Possession of weapons            67.0     47.0    814.0
# Public order                    377.0    341.0   4580.0
# Robbery                          65.0     72.0    841.0
# Shoplifting                     561.0    414.0   6306.0
# Theft from the person           154.0    175.0   1624.0
# Vehicle crime                   460.0    388.0   4830.0
# Violence and sexual offences   1778.0   1679.0  21243.0

# %% [markdown]
# It is also possible to veiw the monthly crimes for the MSOA locations.  Through the SQL call to DB2:

# %%
#query statement to number of crimes by MSOA and Month
selectQuery = "select MS.MSOA01NM, MM.objectid, MS.MSOA01CD, NC.MONTH, count(*) as COUNT \
from NOTTINGHAM_CRIME_2019 as NC join MSOA_LINK as MS on NC.LSOA_CODE = MS.LSOA01CD \
join MSOA_MASTER as MM on MS.MSOA01CD = MM.MSOA11CD group by MS.MSOA01NM, MM.objectid, MS.MSOA01CD, NC.MONTH"

#retrieve the query results into a pandas dataframe
NOTTM_CRIME_MSOA_MONTHdf = pd.read_sql(selectQuery, pconn)

NOTTM_CRIME_MSOA_MONTHdf.rename (columns = {'5':'Number Crimes'}, inplace = True)
#print just the LNAME for first row in the pandas data frame
NOTTM_CRIME_MSOA_MONTHdf.head()
# Out:
#          MSOA01NM  OBJECTID   MSOA01CD    MONTH  COUNT
# 0  Rushcliffe 014       889  E02005919  2019-01   21.0
# 1  Rushcliffe 014       889  E02005919  2019-02   17.0
# 2  Rushcliffe 014       889  E02005919  2019-03   24.0
# 3  Rushcliffe 014       889  E02005919  2019-04   38.0
# 4  Rushcliffe 014       889  E02005919  2019-05   30.0

# %% [markdown]
# Pivot the data to give an improved table of crimes by MSOA per month.

# %%
NOTTM_CRIME_MSOA_MONTH = NOTTM_CRIME_MSOA_MONTHdf.pivot(index='MSOA01NM', columns='MONTH', values='COUNT')
NOTTM_CRIME_MSOA_MONTH['Total'] = NOTTM_CRIME_MSOA_MONTH.sum(axis=1)
NOTTM_CRIME_MSOA_MONTH.head(10)
# Out:
# MONTH         2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  2019-07  \
# MSOA01NM
# Broxtowe 001     33.0     32.0     35.0     45.0     61.0     37.0     43.0
# Broxtowe 002     83.0    102.0     95.0     81.0     69.0     80.0     87.0
# Broxtowe 003     58.0     43.0     45.0     36.0     61.0     70.0     57.0
# Broxtowe 004     53.0     50.0     63.0     70.0     71.0     49.0     48.0
# Broxtowe 007     27.0     21.0     40.0     39.0     33.0     29.0     29.0
# Broxtowe 008     58.0     31.0     62.0     66.0     54.0     66.0     66.0
# Broxtowe 009     37.0     23.0     40.0     38.0     53.0     32.0     51.0
# Broxtowe 010     86.0     55.0     75.0     60.0     77.0     92.0     99.0
# Broxtowe 011    164.0    120.0    135.0    126.0     95.0    128.0    114.0
# Broxtowe 012     40.0     55.0     48.0     44.0     46.0     43.0     44.0
#
# MONTH         2019-08  2019-09  2019-10  2019-11  2019-12   Total
# MSOA01NM
# Broxtowe 001     51.0     44.0     35.0     36.0     45.0   497.0
# Broxtowe 002     71.0     76.0     57.0     93.0    108.0  1002.0
# Broxtowe 003     50.0     49.0     66.0     45.0     29.0   609.0
# Broxtowe 004     45.0     51.0     53.0     56.0     43.0   652.0
# Broxtowe 007     23.0     25.0     23.0     27.0     12.0   328.0
# Broxtowe 008     78.0     46.0     60.0     48.0     53.0   688.0
# Broxtowe 009     45.0     42.0     32.0     32.0     29.0   454.0
# Broxtowe 010     57.0     63.0     68.0     59.0     70.0   861.0
# Broxtowe 011     88.0     96.0     91.0    120.0    111.0  1388.0
# Broxtowe 012     50.0     51.0     28.0     42.0     25.0   516.0

# %% [markdown]
# Whilst useful for the detailed purposes of this analysis, the data can be more easily visualised if displayed for the overall Borough.  The Borough can be found by taking the first part of the Name of the MSOA.

# %%
#query statement to number of crimes by MSOA and Month using only the first 4 characters of MSOA Name to identify the borough. 
selectQuery = "select LEFT(MS.MSOA01NM,4) as BOROUGH, NC.MONTH, count(*) as COUNT \
from NOTTINGHAM_CRIME_2019 as NC join MSOA_LINK as MS on NC.LSOA_CODE = MS.LSOA01CD \
join MSOA_MASTER as MM on MS.MSOA01CD = MM.MSOA11CD group by LEFT(MS.MSOA01NM,4), NC.MONTH"

#retrieve the query results into a pandas dataframe
NOTTM_CRIME_BORO_MONTHdf = pd.read_sql(selectQuery, pconn)

# Replace the first four letters with the full name
NOTTM_CRIME_BORO_MONTHdf["BOROUGH"].replace("Brox", "Broxtowe", inplace = True)
NOTTM_CRIME_BORO_MONTHdf["BOROUGH"].replace("Gedl", "Gedling", inplace = True)
NOTTM_CRIME_BORO_MONTHdf["BOROUGH"].replace("Nott", "Nottingham", inplace = True)
NOTTM_CRIME_BORO_MONTHdf["BOROUGH"].replace("Rush", "Rushcliffe", inplace = True)

NOTTM_CRIME_BORO_MONTHdf.rename (columns = {'5':'Number Crimes'}, inplace = True)
#print just the LNAME for first row in the pandas data frame
NOTTM_CRIME_BORO_MONTHdf.head()
# Out:
#     BOROUGH    MONTH  COUNT
# 0  Broxtowe  2019-01  737.0
# 1  Broxtowe  2019-02  667.0
# 2  Broxtowe  2019-03  766.0
# 3  Broxtowe  2019-04  719.0
# 4  Broxtowe  2019-05  732.0

# %%
NOTTM_CRIME_BORO_MONTH = NOTTM_CRIME_BORO_MONTHdf.pivot(index='BOROUGH',columns='MONTH', values='COUNT')
NOTTM_CRIME_BORO_MONTH['Total'] = NOTTM_CRIME_BORO_MONTH.sum(axis=1)
NOTTM_CRIME_BORO_MONTH.head(10)
# Out:
# MONTH       2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  2019-07  \
# BOROUGH
# Broxtowe      737.0    667.0    766.0    719.0    732.0    772.0    797.0
# Gedling       628.0    624.0    701.0    700.0    702.0    711.0    755.0
# Nottingham   2981.0   2907.0   3250.0   3173.0   3305.0   3286.0   3566.0
# Rushcliffe    505.0    472.0    518.0    590.0    608.0    602.0    732.0
#
# MONTH       2019-08  2019-09  2019-10  2019-11  2019-12    Total
# BOROUGH
# Broxtowe      685.0    683.0    655.0    665.0    629.0   8507.0
# Gedling       693.0    616.0    710.0    635.0    607.0   8082.0
# Nottingham   3216.0   3057.0   3386.0   3030.0   2762.0  37919.0
# Rushcliffe    596.0    606.0    595.0    585.0    496.0   6905.0

# %% [markdown]
# Similarly, it is possible to load information regarding the MSOA number of Crimes by Crime type, and also summarise that by Borough.

# %%
#query statement to retrieve number of crimes by MSOA and Crime Type
selectQuery = "select MS.MSOA01NM, MM.objectid, MS.MSOA01CD, NC.CRIME_TYPE, count(*) as COUNT \
from NOTTINGHAM_CRIME_2019 as NC join MSOA_LINK as MS on NC.LSOA_CODE = MS.LSOA01CD \
join MSOA_MASTER as MM on MS.MSOA01CD = MM.MSOA11CD \
group by MM.ObjectId, MS.MSOA01CD, MS.MSOA01NM, NC.CRIME_TYPE"

#retrieve the query results into a pandas dataframe
NOTTM_CRIME_MSOA_CTdf = pd.read_sql(selectQuery, pconn)

NOTTM_CRIME_MSOA_CTdf.rename (columns = {'5':'COUNT'}, inplace = True)
#print just the LNAME for first row in the pandas data frame
NOTTM_CRIME_MSOA_CTdf.head()

NOTTM_CRIME_MSOA_CT = NOTTM_CRIME_MSOA_CTdf.pivot_table(index=['MSOA01NM','MSOA01CD'], columns='CRIME_TYPE', values='COUNT')
NOTTM_CRIME_MSOA_CT.replace(np.nan, 0, inplace=True)
NOTTM_CRIME_MSOA_CT['Total'] = NOTTM_CRIME_MSOA_CT.sum(axis=1)
NOTTM_CRIME_MSOA_CT.head()

# List of Crimes by type accross the various MSOAs
# Out:
# CRIME_TYPE              Anti-social behaviour  Bicycle theft  Burglary  \
# MSOA01NM     MSOA01CD
# Broxtowe 001 E02005850                   80.0            2.0      31.0
# Broxtowe 002 E02005851                  199.0            4.0      60.0
# Broxtowe 003 E02005852                  106.0            3.0      37.0
# Broxtowe 004 E02005853                  146.0            5.0      62.0
# Broxtowe 007 E02005856                   58.0           17.0      47.0
#
# CRIME_TYPE              Criminal damage and arson  Drugs  Other crime  \
# MSOA01NM     MSOA01CD
# Broxtowe 001 E02005850                       55.0    4.0         12.0
# Broxtowe 002 E02005851                      107.0   13.0         20.0
# Broxtowe 003 E02005852                       35.0    8.0          7.0
# Broxtowe 004 E02005853                       56.0   14.0         16.0
# Broxtowe 007 E02005856                       22.0    5.0          8.0
#
# CRIME_TYPE              Other theft  Possession of weapons  Public order  \
# MSOA01NM     MSOA01CD
# Broxtowe 001 E02005850         39.0                    3.0          15.0
# Broxtowe 002 E02005851         47.0                    6.0          52.0
# Broxtowe 003 E02005852         56.0                    4.0          32.0
# Broxtowe 004 E02005853         37.0                    7.0          33.0
# Broxtowe 007 E02005856         21.0                    3.0          17.0
#
# CRIME_TYPE              Robbery  Shoplifting  Theft from the person  \
# MSOA01NM     MSOA01CD
# Broxtowe 001 E02005850      5.0         99.0                    5.0
# Broxtowe 002 E02005851     10.0        131.0                    9.0
# Broxtowe 003 E02005852      4.0        163.0                    4.0
# Broxtowe 004 E02005853     10.0         66.0                    3.0
# Broxtowe 007 E02005856      2.0          0.0                    4.0
#
# CRIME_TYPE              Vehicle crime  Violence and sexual offences   Total
# MSOA01NM     MSOA01CD
# Broxtowe 001 E02005850           32.0                         115.0   497.0
# Broxtowe 002 E02005851           59.0                         285.0  1002.0
# Broxtowe 003 E02005852           48.0                         102.0   609.0
# Broxtowe 004 E02005853           52.0                         145.0   652.0
# Broxtowe 007 E02005856           30.0                          94.0   328.0

# %%
#query statement to retrieve number of crimes by MSOA and Crime Type
selectQuery = "select left(LSOA_NAME,4) as BOROUGH, CRIME_TYPE, count(*) as COUNT \
from NOTTINGHAM_CRIME_2019 group by LEFT(LSOA_NAME,4), CRIME_TYPE"

selectQuery = "select LEFT(MS.MSOA01NM,4) as BOROUGH, NC.CRIME_TYPE, count(*) as COUNT \
from NOTTINGHAM_CRIME_2019 as NC \
join MSOA_LINK as MS on NC.LSOA_CODE = MS.LSOA01CD \
group by LEFT(MS.MSOA01NM,4), NC.CRIME_TYPE"
#retrieve the query results into a pandas dataframe
NOTTM_CRIME_BORO_CTdf = pd.read_sql(selectQuery, pconn)

# Replace the first four letters with the full name
NOTTM_CRIME_BORO_CTdf["BOROUGH"].replace("Brox", "Broxtowe", inplace = True)
NOTTM_CRIME_BORO_CTdf["BOROUGH"].replace("Gedl", "Gedling", inplace = True)
NOTTM_CRIME_BORO_CTdf["BOROUGH"].replace("Nott", "Nottingham", inplace = True)
NOTTM_CRIME_BORO_CTdf["BOROUGH"].replace("Rush", "Rushcliffe", inplace = True)

NOTTM_CRIME_BORO_CTdf.rename (columns = {'5':'COUNT'}, inplace = True)
#print just the LNAME for first row in the pandas data frame
NOTTM_CRIME_BORO_CTdf.head()

NOTTM_CRIME_BORO_CT = NOTTM_CRIME_BORO_CTdf.pivot(index='BOROUGH', columns='CRIME_TYPE', values='COUNT')
NOTTM_CRIME_BORO_CT['Total'] = NOTTM_CRIME_BORO_CT.sum(axis=1)
NOTTM_CRIME_BORO_CT.head()
# Out:
# CRIME_TYPE  Anti-social behaviour  Bicycle theft  Burglary  \
# BOROUGH
# Broxtowe                   1822.0          220.0     612.0
# Gedling                    1789.0           55.0     540.0
# Nottingham                 9922.0          636.0    1944.0
# Rushcliffe                 1215.0          158.0     603.0
#
# CRIME_TYPE  Criminal damage and arson   Drugs  Other crime  Other theft  \
# BOROUGH
# Broxtowe                        765.0   121.0        169.0        590.0
# Gedling                         884.0   179.0        212.0        578.0
# Nottingham                     3481.0  1427.0        970.0       2774.0
# Rushcliffe                      649.0   146.0        147.0        635.0
#
# CRIME_TYPE  Possession of weapons  Public order  Robbery  Shoplifting  \
# BOROUGH
# Broxtowe                     56.0         457.0     95.0       1127.0
# Gedling                      66.0         409.0     65.0        530.0
# Nottingham                  436.0        2343.0    456.0       2215.0
# Rushcliffe                   37.0         308.0     41.0        389.0
#
# CRIME_TYPE  Theft from the person  Vehicle crime  \
# BOROUGH
# Broxtowe                     82.0          628.0
# Gedling                      70.0          578.0
# Nottingham                  581.0         2172.0
# Rushcliffe                   50.0          791.0
#
# CRIME_TYPE  Violence and sexual offences    Total
# BOROUGH
# Broxtowe                          2273.0   9017.0
# Gedling                           2503.0   8458.0
# Nottingham                       11545.0  40902.0
# Rushcliffe                        1736.0   6905.0

# %% [markdown]
# Finally we should hold a table summary by MSOA with the Code and Object ID for further use.

# %%
#query statement to retrieve number of crimes by MSOA
selectQuery = "select MS.MSOA01CD, MS.MSOA01NM, MM.objectid, count(*) as COUNT \
from NOTTINGHAM_CRIME_2019 as NC join MSOA_LINK as MS on NC.LSOA_CODE = MS.LSOA01CD \
join MSOA_MASTER as MM on MS.MSOA01CD = MM.MSOA11CD \
group by MS.MSOA01CD, MS.MSOA01NM, MM.ObjectId"

#retrieve the query results into a pandas dataframe
NOTTM_CRIME_MSOA = pd.read_sql(selectQuery, pconn)

NOTTM_CRIME_MSOA.rename (columns = {'4':'Number Crimes'}, inplace = True)
#print just the LNAME for first row in the pandas data frame
NOTTM_CRIME_MSOA.head()
# Out:
#     MSOA01CD        MSOA01NM  OBJECTID  COUNT
# 0  E02005919  Rushcliffe 014       889  328.0
# 1  E02005866     Gedling 002      2201  618.0
# 2  E02005864    Broxtowe 015      2202  548.0
# 3  E02005865     Gedling 001      2203  713.0
# 4  E02005862    Broxtowe 013      2204  538.0

# %%
ibm_db.close(conn)
# Out:
# True

# %% [markdown]
# The ONS Geo data website also provides population weighted centroids for Middle Layer Super Output Areas for England and Wales as at 31 December.  This can be selected for a square output area which is set in the url.  The square for Nottingham is from (approximately) Longitude -1.350 Latitude 52.700 (SW corner) to Long. -1.000 Lat 53.200 (NE corner).  A JSON file is returned.

# %% [markdown]
# Population Centroids JSON
# https://ons-inspire.esriuk.com/arcgis/rest/services/Census_Boundaries/Middle_Super_Output_Areas_December_2011_Centroids/MapServer/0/query?where=1%3D1&outFields=*&geometry=-1.350%2C52.700%2C-1.000%2C53.200&geometryType=esriGeometryEnvelope&inSR=4326&spatialRel=esriSpatialRelIntersects&outSR=4326&f=json

# %%
import requests
from pandas.io.json import json_normalize
# Define the URL
url = 'https://ons-inspire.esriuk.com/arcgis/rest/services/Census_Boundaries/Middle_Super_Output_Areas_December_2011_Centroids/MapServer/0/query?where=1%3D1&outFields=*&geometry=-1.350%2C52.700%2C-1.000%2C53.200&geometryType=esriGeometryEnvelope&inSR=4326&spatialRel=esriSpatialRelIntersects&outSR=4326&f=json'

results = requests.get(url).json()

# %% [markdown]
# This is quite a complexly structured JSON file.  For the purposes of this analysis it needs to be stripped back to the 'features layer'.

# %%
## assign relevant part of JSON to MSOA_Centr JSON
MSOA_Centrj = results['features']
MSOA_Centrj
# Out:
# [{'attributes': {'objectid': 806,
#    'msoa11cd': 'E02005405',
#    'msoa11nm': 'North West Leicestershire 009'},
#   'geometry': {'x': -1.333692935682093, 'y': 52.72288846666765}},
#  {'attributes': {'objectid': 810,
#    'msoa11cd': 'E02005403',
#    'msoa11nm': 'North West Leicestershire 007'},
#   'geometry': {'x': -1.3544944882205507, 'y': 52.73823322621531}},
#  {'attributes': {'objectid': 848,
#    'msoa11cd': 'E02005397',
#    'msoa11nm': 'North West Leicestershire 001'},
#   'geometry': {'x': -1.342789487712562, 'y': 52.84162595716862}},
#  {'attributes': {'objectid': 857,
#    'msoa11cd': 'E02005398',
#    'msoa11nm': 'North West Leicestershire 002'},
#   'geometry': {'x': -1.2847744877246043, 'y': 52.83302037944029}},
#  {'attributes': {'objectid': 889,
#    'msoa11cd': 'E02005919',
#    'msoa11nm': 'Rushcliffe 014'},
#   'geometry': {'x': -1.2101654955911696, 'y': 52.851183371126936}},
#  {'attributes': {'objectid': 2242,
#    'msoa11cd': 'E02005920',
#    'msoa11nm': 'Rushcliffe 015'},
#   'geometry': {'x': -1.17991214354001, 'y': 52.83104642733119}},
#  {'attributes': {'objectid': 2292,
#    'msoa11cd': 'E02005360',
#    'msoa11nm': 'Charnwood 016'},
#   'geometry': {'x': -1.1940470720959728, 'y': 52.70827915533768}},
#  {'attributes': {'objectid': 2411,
#    'msoa11cd': 'E02005346',
#    'msoa11nm': 'Charnwood 002'},
#   'geometry': {'x': -1.2022432085254156, 'y': 52.77541747768157}},
#  {'attributes': {'objectid': 2412,
#    'msoa11cd': 'E02005347',
#    'msoa11nm': 'Charnwood 003'},
#   'geometry': {'x': -1.2182568919960828, 'y': 52.7735738330829}},
#  {'attributes': {'objectid': 2414,
#    'msoa11cd': 'E02005345',
#    'msoa11nm': 'Charnwood 001'},
#   'geometry': {'x': -1.2421813106348878, 'y': 52.783594544365904}},
#  {'attributes': {'objectid': 2419,
#    'msoa11cd': 'E02005348',
#    'msoa11nm': 'Charnwood 004'},
#   'geometry': {'x': -1.2428688483839991, 'y': 52.7735807243468}},
#  {'attributes': {'objectid': 2420,
#    'msoa11cd': 'E02005349',
#    'msoa11nm': 'Charnwood 005'},
#   'geometry': {'x': -1.297807153223629, 'y': 52.769597778783634}},
#  {'attributes': {'objectid': 2443,
#    'msoa11cd': 'E02005917',
#    'msoa11nm': 'Rushcliffe 012'},
#   'geometry': {'x': -1.0861257860907048, 'y': 52.88060210354252}},
#  {'attributes': {'objectid': 2455,
#    'msoa11cd': 'E02005918',
#    'msoa11nm': 'Rushcliffe 013'},
#   'geometry': {'x': -1.0874138761365197, 'y': 52.873680619626995}},
#  {'attributes': {'objectid': 2490,
#    'msoa11cd': 'E02005356',
#    'msoa11nm': 'Charnwood 012'},
#   'geometry': {'x': -1.1701255733206715, 'y': 52.743771764927494}},
#  {'attributes': {'objectid': 2491,
#    'msoa11cd': 'E02005357',
#    'msoa11nm': 'Charnwood 013'},
#   'geometry': {'x': -1.104296514698809, 'y': 52.731849711233856}},
#  {'attributes': {'objectid': 2492,
#    'msoa11cd': 'E02005354',
#    'msoa11nm': 'Charnwood 010'},
#   'geometry': {'x': -1.221645405144404, 'y': 52.75428346071836}},
#  {'attributes': {'objectid': 2493,
#    'msoa11cd': 'E02005355',
#    'msoa11nm': 'Charnwood 011'},
#   'geometry': {'x': -1.1442579388058345, 'y': 52.75248144646111}},
#  {'attributes': {'objectid': 2494,
#    'msoa11cd': 'E02005352',
#    'msoa11nm': 'Charnwood 008'},
#   'geometry': {'x': -1.0999474533872289, 'y': 52.769649642414194}},
#  {'attributes': {'objectid': 2495,
#    'msoa11cd': 'E02005353',
#    'msoa11nm': 'Charnwood 009'},
#   'geometry': {'x': -1.2041919154076983, 'y': 52.75928204722595}},
#  {'attributes': {'objectid': 2496,
#    'msoa11cd': 'E02005350',
#    'msoa11nm': 'Charnwood 006'},
#   'geometry': {'x': -1.2871894254650165, 'y': 52.767605074513085}},
#  {'attributes': {'objectid': 2497,
#    'msoa11cd': 'E02005351',
#    'msoa11nm': 'Charnwood 007'},
#   'geometry': {'x': -1.2350546358202041, 'y': 52.765558703866375}},
#  {'attributes': {'objectid': 2498,
#    'msoa11cd': 'E02005358',
#    'msoa11nm': 'Charnwood 014'},
#   'geometry': {'x': -1.1405550087627172, 'y': 52.72043557514287}},
#  {'attributes': {'objectid': 2499,
#    'msoa11cd': 'E02005359',
#    'msoa11nm': 'Charnwood 015'},
#   'geometry': {'x': -1.0515264582858084, 'y': 52.71072600184396}},
#  {'attributes': {'objectid': 783,
#    'msoa11cd': 'E02005892',
#    'msoa11nm': 'Mansfield 013'},
#   'geometry': {'x': -1.1842433969994468, 'y': 53.13194565184799}},
#  {'attributes': {'objectid': 784,
#    'msoa11cd': 'E02005891',
#    'msoa11nm': 'Mansfield 012'},
#   'geometry': {'x': -1.1518914156713116, 'y': 53.13362246364972}},
#  {'attributes': {'objectid': 785,
#    'msoa11cd': 'E02005890',
#    'msoa11nm': 'Mansfield 011'},
#   'geometry': {'x': -1.1647013866639802, 'y': 53.140442772556376}},
#  {'attributes': {'objectid': 789,
#    'msoa11cd': 'E02005819',
#    'msoa11nm': 'Ashfield 001'},
#   'geometry': {'x': -1.2726660244361518, 'y': 53.1431752647556}},
#  {'attributes': {'objectid': 790,
#    'msoa11cd': 'E02005898',
#    'msoa11nm': 'Newark and Sherwood 006'},
#   'geometry': {'x': -1.110808784922112, 'y': 53.11257721664657}},
#  {'attributes': {'objectid': 860,
#    'msoa11cd': 'E02005886',
#    'msoa11nm': 'Mansfield 007'},
#   'geometry': {'x': -1.157433077380453, 'y': 53.15578051319723}},
#  {'attributes': {'objectid': 862,
#    'msoa11cd': 'E02005885',
#    'msoa11nm': 'Mansfield 006'},
#   'geometry': {'x': -1.2244966169909433, 'y': 53.157270954329846}},
#  {'attributes': {'objectid': 864,
#    'msoa11cd': 'E02005884',
#    'msoa11nm': 'Mansfield 005'},
#   'geometry': {'x': -1.184619009665239, 'y': 53.16128824941698}},
#  {'attributes': {'objectid': 866,
#    'msoa11cd': 'E02005883',
#    'msoa11nm': 'Mansfield 004'},
#   'geometry': {'x': -1.1984269414645976, 'y': 53.16556007797176}},
#  {'attributes': {'objectid': 868,
#    'msoa11cd': 'E02005882',
#    'msoa11nm': 'Mansfield 003'},
#   'geometry': {'x': -1.1806043919153004, 'y': 53.17167722357629}},
#  {'attributes': {'objectid': 873,
#    'msoa11cd': 'E02005889',
#    'msoa11nm': 'Mansfield 010'},
#   'geometry': {'x': -1.221944488165066, 'y': 53.141945126027956}},
#  {'attributes': {'objectid': 874,
#    'msoa11cd': 'E02005888',
#    'msoa11nm': 'Mansfield 009'},
#   'geometry': {'x': -1.181234147451087, 'y': 53.14458535539482}},
#  {'attributes': {'objectid': 2163,
#    'msoa11cd': 'E02005897',
#    'msoa11nm': 'Newark and Sherwood 005'},
#   'geometry': {'x': -1.0292371898325015, 'y': 53.12453183700687}},
#  {'attributes': {'objectid': 2170,
#    'msoa11cd': 'E02005894',
#    'msoa11nm': 'Newark and Sherwood 002'},
#   'geometry': {'x': -1.0802741891713292, 'y': 53.18539250177658}},
#  {'attributes': {'objectid': 2203,
#    'msoa11cd': 'E02005865',
#    'msoa11nm': 'Gedling 001'},
#   'geometry': {'x': -1.1650541174861608, 'y': 53.084128762154045}},
#  {'attributes': {'objectid': 2465,
#    'msoa11cd': 'E02004054',
#    'msoa11nm': 'Bolsover 010'},
#   'geometry': {'x': -1.3265236301304462, 'y': 53.095942361578835}},
#  {'attributes': {'objectid': 2467,
#    'msoa11cd': 'E02005826',
#    'msoa11nm': 'Ashfield 008'},
#   'geometry': {'x': -1.2560308711923929, 'y': 53.10327862743637}},
#  {'attributes': {'objectid': 2470,
#    'msoa11cd': 'E02005827',
#    'msoa11nm': 'Ashfield 009'},
#   'geometry': {'x': -1.2598911627512301, 'y': 53.09974490859479}},
#  {'attributes': {'objectid': 2472,
#    'msoa11cd': 'E02005824',
#    'msoa11nm': 'Ashfield 006'},
#   'geometry': {'x': -1.2775176342884733, 'y': 53.12162186598487}},
#  {'attributes': {'objectid': 2473,
#    'msoa11cd': 'E02004053',
#    'msoa11nm': 'Bolsover 009'},
#   'geometry': {'x': -1.3405908349338251, 'y': 53.10515447991316}},
#  {'attributes': {'objectid': 2474,
#    'msoa11cd': 'E02005825',
#    'msoa11nm': 'Ashfield 007'},
#   'geometry': {'x': -1.2356228761799306, 'y': 53.10263224623493}},
#  {'attributes': {'objectid': 2476,
#    'msoa11cd': 'E02005822',
#    'msoa11nm': 'Ashfield 004'},
#   'geometry': {'x': -1.2492529752190267, 'y': 53.12856089691693}},
#  {'attributes': {'objectid': 2477,
#    'msoa11cd': 'E02004051',
#    'msoa11nm': 'Bolsover 007'},
#   'geometry': {'x': -1.2184235742252305, 'y': 53.20113869370938}},
#  {'attributes': {'objectid': 2478,
#    'msoa11cd': 'E02005823',
#    'msoa11nm': 'Ashfield 005'},
#   'geometry': {'x': -1.2652082640176017, 'y': 53.12525057859868}},
#  {'attributes': {'objectid': 2479,
#    'msoa11cd': 'E02005820',
#    'msoa11nm': 'Ashfield 002'},
#   'geometry': {'x': -1.2544999565360062, 'y': 53.13621607562692}},
#  {'attributes': {'objectid': 2480,
#    'msoa11cd': 'E02005821',
#    'msoa11nm': 'Ashfield 003'},
#   'geometry': {'x': -1.2992325184146658, 'y': 53.127080053817096}},
#  {'attributes': {'objectid': 2600,
#    'msoa11cd': 'E02005887',
#    'msoa11nm': 'Mansfield 008'},
#   'geometry': {'x': -1.2046218005929943, 'y': 53.14548161890339}},
#  {'attributes': {'objectid': 782,
#    'msoa11cd': 'E02004080',
#    'msoa11nm': 'Erewash 003'},
#   'geometry': {'x': -1.3042284888166316, 'y': 52.97081653730062}},
#  {'attributes': {'objectid': 786,
#    'msoa11cd': 'E02004089',
#    'msoa11nm': 'Erewash 012'},
#   'geometry': {'x': -1.2712189089325332, 'y': 52.89783515663778}},
#  {'attributes': {'objectid': 787,
#    'msoa11cd': 'E02004088',
#    'msoa11nm': 'Erewash 011'},
#   'geometry': {'x': -1.2959619279508237, 'y': 52.897436615562484}},
#  {'attributes': {'objectid': 844,
#    'msoa11cd': 'E02004092',
#    'msoa11nm': 'Erewash 015'},
#   'geometry': {'x': -1.2949231098794498, 'y': 52.885277261529566}},
#  {'attributes': {'objectid': 845,
#    'msoa11cd': 'E02004091',
#    'msoa11nm': 'Erewash 014'},
#   'geometry': {'x': -1.2733326861954573, 'y': 52.88891175411706}},
#  {'attributes': {'objectid': 846,
#    'msoa11cd': 'E02004090',
#    'msoa11nm': 'Erewash 013'},
#   'geometry': {'x': -1.3337230193335783, 'y': 52.89636217782948}},
#  {'attributes': {'objectid': 2159,
#    'msoa11cd': 'E02004087',
#    'msoa11nm': 'Erewash 010'},
#   'geometry': {'x': -1.2882315126610138, 'y': 52.90909700419141}},
#  {'attributes': {'objectid': 2161,
#    'msoa11cd': 'E02004085',
#    'msoa11nm': 'Erewash 008'},
#   'geometry': {'x': -1.2946866626781268, 'y': 52.923879423383276}},
#  {'attributes': {'objectid': 2164,
#    'msoa11cd': 'E02004084',
#    'msoa11nm': 'Erewash 007'},
#   'geometry': {'x': -1.324368384792261, 'y': 52.95801270525535}},
#  {'attributes': {'objectid': 2167,
#    'msoa11cd': 'E02004083',
#    'msoa11nm': 'Erewash 006'},
#   'geometry': {'x': -1.2994500756294087, 'y': 52.960524292485786}},
#  {'attributes': {'objectid': 2198,
#    'msoa11cd': 'E02006904',
#    'msoa11nm': 'Nottingham 039'},
#   'geometry': {'x': -1.1428406039649401, 'y': 52.949555795779624}},
#  {'attributes': {'objectid': 2199,
#    'msoa11cd': 'E02006905',
#    'msoa11nm': 'Nottingham 040'},
#   'geometry': {'x': -1.1501764221393287, 'y': 52.94064159364265}},
#  {'attributes': {'objectid': 2202,
#    'msoa11cd': 'E02005864',
#    'msoa11nm': 'Broxtowe 015'},
#   'geometry': {'x': -1.2572794657790536, 'y': 52.90806189353683}},
#  {'attributes': {'objectid': 2204,
#    'msoa11cd': 'E02005862',
#    'msoa11nm': 'Broxtowe 013'},
#   'geometry': {'x': -1.244654435895579, 'y': 52.918487780743035}},
#  {'attributes': {'objectid': 2205,
#    'msoa11cd': 'E02005863',
#    'msoa11nm': 'Broxtowe 014'},
#   'geometry': {'x': -1.231201262724046, 'y': 52.91861080519052}},
#  {'attributes': {'objectid': 2206,
#    'msoa11cd': 'E02005860',
#    'msoa11nm': 'Broxtowe 011'},
#   'geometry': {'x': -1.2118757364472346, 'y': 52.92602999845936}},
#  {'attributes': {'objectid': 2207,
#    'msoa11cd': 'E02005861',
#    'msoa11nm': 'Broxtowe 012'},
#   'geometry': {'x': -1.2037957875162477, 'y': 52.91927641699924}},
#  {'attributes': {'objectid': 2213,
#    'msoa11cd': 'E02002887',
#    'msoa11nm': 'Nottingham 020'},
#   'geometry': {'x': -1.2127011538639285, 'y': 52.96551095724812}},
#  {'attributes': {'objectid': 2215,
#    'msoa11cd': 'E02002886',
#    'msoa11nm': 'Nottingham 019'},
#   'geometry': {'x': -1.1882402645000725, 'y': 52.96598227978929}},
#  {'attributes': {'objectid': 2217,
#    'msoa11cd': 'E02002885',
#    'msoa11nm': 'Nottingham 018'},
#   'geometry': {'x': -1.1720955090581848, 'y': 52.966627629245394}},
#  {'attributes': {'objectid': 2219,
#    'msoa11cd': 'E02002884',
#    'msoa11nm': 'Nottingham 017'},
#   'geometry': {'x': -1.1619356781192147, 'y': 52.97034806302552}},
#  {'attributes': {'objectid': 2221,
#    'msoa11cd': 'E02002883',
#    'msoa11nm': 'Nottingham 016'},
#   'geometry': {'x': -1.1260557943476364, 'y': 52.97003555298711}},
#  {'attributes': {'objectid': 2223,
#    'msoa11cd': 'E02002882',
#    'msoa11nm': 'Nottingham 015'},
#   'geometry': {'x': -1.1469469916589776, 'y': 52.97170982404751}},
#  {'attributes': {'objectid': 2225,
#    'msoa11cd': 'E02002881',
#    'msoa11nm': 'Nottingham 014'},
#   'geometry': {'x': -1.2267304257175973, 'y': 52.974496201721436}},
#  {'attributes': {'objectid': 2227,
#    'msoa11cd': 'E02002880',
#    'msoa11nm': 'Nottingham 013'},
#   'geometry': {'x': -1.2017664462826576, 'y': 52.97644973306043}},
#  {'attributes': {'objectid': 2229,
#    'msoa11cd': 'E02002889',
#    'msoa11nm': 'Nottingham 022'},
#   'geometry': {'x': -1.1605525435582758, 'y': 52.95999756446661}},
#  {'attributes': {'objectid': 2231,
#    'msoa11cd': 'E02002888',
#    'msoa11nm': 'Nottingham 021'},
#   'geometry': {'x': -1.130901953170846, 'y': 52.96252803142331}},
#  {'attributes': {'objectid': 2248,
#    'msoa11cd': 'E02005876',
#    'msoa11nm': 'Gedling 012'},
#   'geometry': {'x': -1.0794638564189123, 'y': 52.97395394752773}},
#  {'attributes': {'objectid': 2250,
#    'msoa11cd': 'E02005877',
#    'msoa11nm': 'Gedling 013'},
#   'geometry': {'x': -1.1112201009411122, 'y': 52.970407593347325}},
#  {'attributes': {'objectid': 2252,
#    'msoa11cd': 'E02005874',
#    'msoa11nm': 'Gedling 010'},
#   'geometry': {'x': -1.113559318000714, 'y': 52.980947397608894}},
#  {'attributes': {'objectid': 2254,
#    'msoa11cd': 'E02005875',
#    'msoa11nm': 'Gedling 011'},
#   'geometry': {'x': -1.0952794067108294, 'y': 52.97798242723155}},
#  {'attributes': {'objectid': 2263,
#    'msoa11cd': 'E02005878',
#    'msoa11nm': 'Gedling 014'},
#   'geometry': {'x': -1.0944509988488087, 'y': 52.965111734237745}},
#  {'attributes': {'objectid': 2264,
#    'msoa11cd': 'E02005879',
#    'msoa11nm': 'Gedling 015'},
#   'geometry': {'x': -1.0776866457089567, 'y': 52.962154924497625}},
#  {'attributes': {'objectid': 2267,
#    'msoa11cd': 'E02002897',
#    'msoa11nm': 'Nottingham 030'},
#   'geometry': {'x': -1.2309887555945274, 'y': 52.94869234710198}},
#  {'attributes': {'objectid': 2269,
#    'msoa11cd': 'E02002896',
#    'msoa11nm': 'Nottingham 029'},
#   'geometry': {'x': -1.1265414269248095, 'y': 52.951708561223036}},
#  {'attributes': {'objectid': 2271,
#    'msoa11cd': 'E02002895',
#    'msoa11nm': 'Nottingham 028'},
#   'geometry': {'x': -1.1659588718772582, 'y': 52.9537383013994}},
#  {'attributes': {'objectid': 2273,
#    'msoa11cd': 'E02002894',
#    'msoa11nm': 'Nottingham 027'},
#   'geometry': {'x': -1.2052151710511267, 'y': 52.956869320717615}},
#  {'attributes': {'objectid': 2275,
#    'msoa11cd': 'E02002893',
#    'msoa11nm': 'Nottingham 026'},
#   'geometry': {'x': -1.1778356394725158, 'y': 52.957812321726756}},
#  {'attributes': {'objectid': 2277,
#    'msoa11cd': 'E02002892',
#    'msoa11nm': 'Nottingham 025'},
#   'geometry': {'x': -1.2367863688186227, 'y': 52.95921182117835}},
#  {'attributes': {'objectid': 2279,
#    'msoa11cd': 'E02002891',
#    'msoa11nm': 'Nottingham 024'},
#   'geometry': {'x': -1.11132798897387, 'y': 52.95941494443554}},
#  {'attributes': {'objectid': 2280,
#    'msoa11cd': 'E02006828',
#    'msoa11nm': 'Erewash 016'},
#   'geometry': {'x': -1.3204560414613822, 'y': 52.983483320697374}},
#  {'attributes': {'objectid': 2282,
#    'msoa11cd': 'E02002890',
#    'msoa11nm': 'Nottingham 023'},
#   'geometry': {'x': -1.1443849396942782, 'y': 52.959117873617544}},
#  {'attributes': {'objectid': 2284,
#    'msoa11cd': 'E02002899',
#    'msoa11nm': 'Nottingham 032'},
#   'geometry': {'x': -1.2038198311058879, 'y': 52.939600151402935}},
#  {'attributes': {'objectid': 2286,
#    'msoa11cd': 'E02002898',
#    'msoa11nm': 'Nottingham 031'},
#   'geometry': {'x': -1.1747483061614803, 'y': 52.94727635424585}},
#  {'attributes': {'objectid': 2381,
#    'msoa11cd': 'E02005908',
#    'msoa11nm': 'Rushcliffe 003'},
#   'geometry': {'x': -1.0321413546760623, 'y': 52.948748267829345}},
#  {'attributes': {'objectid': 2382,
#    'msoa11cd': 'E02005909',
#    'msoa11nm': 'Rushcliffe 004'},
#   'geometry': {'x': -1.1202230921449885, 'y': 52.935142594034666}},
#  {'attributes': {'objectid': 2396,
#    'msoa11cd': 'E02005856',
#    'msoa11nm': 'Broxtowe 007'},
#   'geometry': {'x': -1.2422874015796712, 'y': 52.93891405462664}},
#  {'attributes': {'objectid': 2398,
#    'msoa11cd': 'E02005857',
#    'msoa11nm': 'Broxtowe 008'},
#   'geometry': {'x': -1.2708862103372924, 'y': 52.93811787972493}},
#  {'attributes': {'objectid': 2409,
#    'msoa11cd': 'E02005858',
#    'msoa11nm': 'Broxtowe 009'},
#   'geometry': {'x': -1.2201939731274294, 'y': 52.93375324911821}},
#  {'attributes': {'objectid': 2410,
#    'msoa11cd': 'E02005859',
#    'msoa11nm': 'Broxtowe 010'},
#   'geometry': {'x': -1.2708689869116505, 'y': 52.92704165389611}},
#  {'attributes': {'objectid': 2441,
#    'msoa11cd': 'E02005916',
#    'msoa11nm': 'Rushcliffe 011'},
#   'geometry': {'x': -1.1510228114878787, 'y': 52.8937821614574}},
#  {'attributes': {'objectid': 2445,
#    'msoa11cd': 'E02005914',
#    'msoa11nm': 'Rushcliffe 009'},
#   'geometry': {'x': -1.0359866947099465, 'y': 52.9071311887319}},
#  {'attributes': {'objectid': 2449,
#    'msoa11cd': 'E02005912',
#    'msoa11nm': 'Rushcliffe 007'},
#   'geometry': {'x': -1.1475848636287498, 'y': 52.918303285473776}},
#  {'attributes': {'objectid': 2450,
#    'msoa11cd': 'E02005913',
#    'msoa11nm': 'Rushcliffe 008'},
#   'geometry': {'x': -1.120191639847743, 'y': 52.916611077655034}},
#  {'attributes': {'objectid': 2451,
#    'msoa11cd': 'E02005910',
#    'msoa11nm': 'Rushcliffe 005'},
#   'geometry': {'x': -1.1319480997012823, 'y': 52.929481167044784}},
#  {'attributes': {'objectid': 2452,
#    'msoa11cd': 'E02005911',
#    'msoa11nm': 'Rushcliffe 006'},
#   'geometry': {'x': -1.108623861879805, 'y': 52.924613601468586}},
#  {'attributes': {'objectid': 2457,
#    'msoa11cd': 'E02002877',
#    'msoa11nm': 'Nottingham 010'},
#   'geometry': {'x': -1.1456028469129451, 'y': 52.98081045810042}},
#  {'attributes': {'objectid': 2466,
#    'msoa11cd': 'E02002878',
#    'msoa11nm': 'Nottingham 011'},
#   'geometry': {'x': -1.2126877919119785, 'y': 52.97990153984704}},
#  {'attributes': {'objectid': 2469,
#    'msoa11cd': 'E02002879',
#    'msoa11nm': 'Nottingham 012'},
#   'geometry': {'x': -1.1654438684705997, 'y': 52.978726237170434}},
#  {'attributes': {'objectid': 2580,
#    'msoa11cd': 'E02002904',
#    'msoa11nm': 'Nottingham 037'},
#   'geometry': {'x': -1.1785709132500093, 'y': 52.89781509475133}},
#  {'attributes': {'objectid': 2581,
#    'msoa11cd': 'E02002902',
#    'msoa11nm': 'Nottingham 035'},
#   'geometry': {'x': -1.1771520721463826, 'y': 52.90833956002571}},
#  {'attributes': {'objectid': 2582,
#    'msoa11cd': 'E02002903',
#    'msoa11nm': 'Nottingham 036'},
#   'geometry': {'x': -1.1909260906601207, 'y': 52.901660662720374}},
#  {'attributes': {'objectid': 2583,
#    'msoa11cd': 'E02002901',
#    'msoa11nm': 'Nottingham 034'},
#   'geometry': {'x': -1.1635369188633005, 'y': 52.91828615047565}},
#  {'attributes': {'objectid': 884,
#    'msoa11cd': 'E02006827',
#    'msoa11nm': 'Amber Valley 017'},
#   'geometry': {'x': -1.3449013145421083, 'y': 53.00737823356216}},
#  {'attributes': {'objectid': 890,
#    'msoa11cd': 'E02005831',
#    'msoa11nm': 'Ashfield 013'},
#   'geometry': {'x': -1.196458885048413, 'y': 53.041300660749044}},
#  {'attributes': {'objectid': 2197,
#    'msoa11cd': 'E02006906',
#    'msoa11nm': 'Broxtowe 016'},
#   'geometry': {'x': -1.2506175464826337, 'y': 52.98509322802297}},
#  {'attributes': {'objectid': 2201,
#    'msoa11cd': 'E02005866',
#    'msoa11nm': 'Gedling 002'},
#   'geometry': {'x': -1.0819793822580663, 'y': 53.03842667300355}},
#  {'attributes': {'objectid': 2208,
#    'msoa11cd': 'E02005868',
#    'msoa11nm': 'Gedling 004'},
#   'geometry': {'x': -1.1244798689759181, 'y': 53.010986318608914}},
#  {'attributes': {'objectid': 2209,
#    'msoa11cd': 'E02005869',
#    'msoa11nm': 'Gedling 005'},
#   'geometry': {'x': -1.1208073081446563, 'y': 53.00447960952835}},
#  {'attributes': {'objectid': 2256,
#    'msoa11cd': 'E02005872',
#    'msoa11nm': 'Gedling 008'},
#   'geometry': {'x': -1.0457966491993955, 'y': 52.9906349024309}},
#  {'attributes': {'objectid': 2258,
#    'msoa11cd': 'E02005873',
#    'msoa11nm': 'Gedling 009'},
#   'geometry': {'x': -1.1254483742842383, 'y': 52.991442779904716}},
#  {'attributes': {'objectid': 2259,
#    'msoa11cd': 'E02005870',
#    'msoa11nm': 'Gedling 006'},
#   'geometry': {'x': -1.1384110698819365, 'y': 53.002179785949615}},
#  {'attributes': {'objectid': 2260,
#    'msoa11cd': 'E02005871',
#    'msoa11nm': 'Gedling 007'},
#   'geometry': {'x': -1.1083306351188384, 'y': 53.0016275483767}},
#  {'attributes': {'objectid': 2340,
#    'msoa11cd': 'E02004078',
#    'msoa11nm': 'Erewash 001'},
#   'geometry': {'x': -1.3095040365493777, 'y': 52.98958075018854}},
#  {'attributes': {'objectid': 2341,
#    'msoa11cd': 'E02006834',
#    'msoa11nm': 'Nottingham 038'},
#   'geometry': {'x': -1.158092855356475, 'y': 53.005934052442}},
#  {'attributes': {'objectid': 2342,
#    'msoa11cd': 'E02006835',
#    'msoa11nm': 'Gedling 016'},
#   'geometry': {'x': -1.1612813377761115, 'y': 53.014331341415655}},
#  {'attributes': {'objectid': 2376,
#    'msoa11cd': 'E02005905',
#    'msoa11nm': 'Newark and Sherwood 013'},
#   'geometry': {'x': -1.0010456442592213, 'y': 53.01175564192381}},
#  {'attributes': {'objectid': 2395,
#    'msoa11cd': 'E02002868',
#    'msoa11nm': 'Nottingham 001'},
#   'geometry': {'x': -1.1750869623475886, 'y': 53.00912114768801}},
#  {'attributes': {'objectid': 2397,
#    'msoa11cd': 'E02002869',
#    'msoa11nm': 'Nottingham 002'},
#   'geometry': {'x': -1.1981043636528217, 'y': 53.00720182816175}},
#  {'attributes': {'objectid': 2401,
#    'msoa11cd': 'E02004041',
#    'msoa11nm': 'Amber Valley 013'},
#   'geometry': {'x': -1.3430880467994937, 'y': 53.012771137364204}},
#  {'attributes': {'objectid': 2402,
#    'msoa11cd': 'E02005852',
#    'msoa11nm': 'Broxtowe 003'},
#   'geometry': {'x': -1.288544585218566, 'y': 53.009855480550684}},
#  {'attributes': {'objectid': 2403,
#    'msoa11cd': 'E02005853',
#    'msoa11nm': 'Broxtowe 004'},
#   'geometry': {'x': -1.2528600924297146, 'y': 53.000198604162264}},
#  {'attributes': {'objectid': 2404,
#    'msoa11cd': 'E02005850',
#    'msoa11nm': 'Broxtowe 001'},
#   'geometry': {'x': -1.2987303628068925, 'y': 53.022461245928895}},
#  {'attributes': {'objectid': 2405,
#    'msoa11cd': 'E02005851',
#    'msoa11nm': 'Broxtowe 002'},
#   'geometry': {'x': -1.3067690581018567, 'y': 53.014526894750134}},
#  {'attributes': {'objectid': 2456,
#    'msoa11cd': 'E02002876',
#    'msoa11nm': 'Nottingham 009'},
#   'geometry': {'x': -1.1885367765874657, 'y': 52.9830886431104}},
#  {'attributes': {'objectid': 2458,
#    'msoa11cd': 'E02002874',
#    'msoa11nm': 'Nottingham 007'},
#   'geometry': {'x': -1.1477806677009998, 'y': 52.98957592077187}},
#  {'attributes': {'objectid': 2459,
#    'msoa11cd': 'E02002875',
#    'msoa11nm': 'Nottingham 008'},
#   'geometry': {'x': -1.1768457269810637, 'y': 52.98894949438008}},
#  {'attributes': {'objectid': 2460,
#    'msoa11cd': 'E02002872',
#    'msoa11nm': 'Nottingham 005'},
#   'geometry': {'x': -1.2078940912672094, 'y': 52.99724588018897}},
#  {'attributes': {'objectid': 2461,
#    'msoa11cd': 'E02002873',
#    'msoa11nm': 'Nottingham 006'},
#   'geometry': {'x': -1.1650536641289209, 'y': 52.99538555953808}},
#  {'attributes': {'objectid': 2462,
#    'msoa11cd': 'E02002871',
#    'msoa11nm': 'Nottingham 004'},
#   'geometry': {'x': -1.1882052849871956, 'y': 52.99856611328339}},
#  {'attributes': {'objectid': 2486,
#    'msoa11cd': 'E02005828',
#    'msoa11nm': 'Ashfield 010'},
#   'geometry': {'x': -1.2526151213268275, 'y': 53.080413411944185}},
#  {'attributes': {'objectid': 2487,
#    'msoa11cd': 'E02005829',
#    'msoa11nm': 'Ashfield 011'},
#   'geometry': {'x': -1.3004100707760666, 'y': 53.073438524058766}},
#  {'attributes': {'objectid': 2542,
#    'msoa11cd': 'E02005834',
#    'msoa11nm': 'Ashfield 016'},
#   'geometry': {'x': -1.2189083998846628, 'y': 53.02699872756955}},
#  {'attributes': {'objectid': 2544,
#    'msoa11cd': 'E02005832',
#    'msoa11nm': 'Ashfield 014'},
#   'geometry': {'x': -1.2043998239091653, 'y': 53.03661497179792}},
#  {'attributes': {'objectid': 2545,
#    'msoa11cd': 'E02005833',
#    'msoa11nm': 'Ashfield 015'},
#   'geometry': {'x': -1.226716641872579, 'y': 53.03352625434689}},
#  {'attributes': {'objectid': 2546,
#    'msoa11cd': 'E02005830',
#    'msoa11nm': 'Ashfield 012'},
#   'geometry': {'x': -1.3213177678969934, 'y': 53.058536758349895}},
#  {'attributes': {'objectid': 2471,
#    'msoa11cd': 'E02004052',
#    'msoa11nm': 'Bolsover 008'},
#   'geometry': {'x': -1.3435458185873328, 'y': 53.13926218863009}}]

# %% [markdown]
# The simplified JSON should be tranformed into a dataframe.

# %%
# tranform MSOA_Centrj into a dataframe
MSOA_Centroids_df = json_normalize(MSOA_Centrj)
MSOA_Centroids_df.head()
# Out:
#   attributes.msoa11cd            attributes.msoa11nm  attributes.objectid  \
# 0           E02005405  North West Leicestershire 009                  806
# 1           E02005403  North West Leicestershire 007                  810
# 2           E02005397  North West Leicestershire 001                  848
# 3           E02005398  North West Leicestershire 002                  857
# 4           E02005919                 Rushcliffe 014                  889
#
#    geometry.x  geometry.y
# 0   -1.333693   52.722888
# 1   -1.354494   52.738233
# 2   -1.342789   52.841626
# 3   -1.284774   52.833020
# 4   -1.210165   52.851183

# %%
MSOA_Centroids_df.shape
# Out:
# (148, 5)

# %% [markdown]
# The spacial selection of the MSOA centroids has included centroids for MSOAs which are not included in the scope of the problem - that is, they are outside of the Nottingham urban area.  However this means that we can join the Centriods dataframe with the NOTTM_CRIME_MSOA data frame.  To start with we need to make sure that they have a common index.

# %%
MSOA_Centroids_df.rename(columns={'attributes.msoa11cd':'MSOA01CD', 'attributes.msoa11nm':'MSOA Name', 'attributes.objectid':'OBJECTID','geometry.x':'x','geometry.y':'y'}, inplace=True)
#MSOA_Centroids_df.set_index('MSOA01CD', inplace=True)
MSOA_Centroids_df.head()
# Out:
#     MSOA01CD                      MSOA Name  OBJECTID         x          y
# 0  E02005405  North West Leicestershire 009       806 -1.333693  52.722888
# 1  E02005403  North West Leicestershire 007       810 -1.354494  52.738233
# 2  E02005397  North West Leicestershire 001       848 -1.342789  52.841626
# 3  E02005398  North West Leicestershire 002       857 -1.284774  52.833020
# 4  E02005919                 Rushcliffe 014       889 -1.210165  52.851183

# %% [markdown]
# Compare this to the total Crimes by MSOA list calculated previously.

# %%
#NOTTM_CRIME_MSOA.set_index('MSOA01CD', inplace=True)
NOTTM_CRIME_MSOA.head()
# Out:
#     MSOA01CD        MSOA01NM  OBJECTID  COUNT
# 0  E02005919  Rushcliffe 014       889  328.0
# 1  E02005866     Gedling 002      2201  618.0
# 2  E02005864    Broxtowe 015      2202  548.0
# 3  E02005865     Gedling 001      2203  713.0
# 4  E02005862    Broxtowe 013      2204  538.0

# %% [markdown]
# Merge both dataframes on the MSOA code - MSOA01CD, which is common to both.

# %%
NOTTM_CRIME_MSOA_CENT = pd.merge(NOTTM_CRIME_MSOA, MSOA_Centroids_df, on='MSOA01CD', how='left')

NOTTM_CRIME_MSOA_CENT.head()
# Out:
#     MSOA01CD        MSOA01NM  OBJECTID_x  COUNT       MSOA Name  OBJECTID_y  \
# 0  E02005919  Rushcliffe 014         889  328.0  Rushcliffe 014       889.0
# 1  E02005866     Gedling 002        2201  618.0     Gedling 002      2201.0
# 2  E02005864    Broxtowe 015        2202  548.0    Broxtowe 015      2202.0
# 3  E02005865     Gedling 001        2203  713.0     Gedling 001      2203.0
# 4  E02005862    Broxtowe 013        2204  538.0    Broxtowe 013      2204.0
#
#           x          y
# 0 -1.210165  52.851183
# 1 -1.081979  53.038427
# 2 -1.257279  52.908062
# 3 -1.165054  53.084129
# 4 -1.244654  52.918488

# %%
NOTTM_CRIME_MSOA_CENT.dtypes
# Out:
# MSOA01CD       object
# MSOA01NM       object
# OBJECTID_x      int64
# COUNT         float64
# MSOA Name      object
# OBJECTID_y    float64
# x             float64
# y             float64
# dtype: object

# %%
NOTTM_CRIME_MSOA_CENT.shape
# Out:
# (76, 8)

# %% [markdown]
# Clean this up - We only need one Object ID and one MSOA Name.

# %%
NOTTM_CRIME_MSOA_CENT.rename(columns={'OBJECTID_x':'OBJECTID'}, inplace=True)
NOTTM_CRIME_MSOA_CENT.drop(['OBJECTID_y','MSOA01NM'], axis=1, inplace=True)
NOTTM_CRIME_MSOA_CENT.head()
# Out:
#     MSOA01CD  OBJECTID  COUNT       MSOA Name         x          y
# 0  E02005919       889  328.0  Rushcliffe 014 -1.210165  52.851183
# 1  E02005866      2201  618.0     Gedling 002 -1.081979  53.038427
# 2  E02005864      2202  548.0    Broxtowe 015 -1.257279  52.908062
# 3  E02005865      2203  713.0     Gedling 001 -1.165054  53.084129
# 4  E02005862      2204  538.0    Broxtowe 013 -1.244654  52.918488

# %% [markdown]
# We can also join the Dataframe with the breakdown by MSOA and Crime type (NOTTM_CRIME_MSOA_CT) with the Centroids data (MSOA_Centroids_df).

# %%
NOTTM_CRIME_MSOA_CT1 = NOTTM_CRIME_MSOA_CT
NOTTM_CRIME_MSOA_CT.sort_values(by=['MSOA01NM'], inplace=True)
#NOTTM_CRIME_MSOA_CT1.rename(columns={'MSOA01NM':'MSOA Name'}, inplace=True)
NOTTM_CRIME_MSOA_CT1.head()
# Out:
# CRIME_TYPE              Anti-social behaviour  Bicycle theft  Burglary  \
# MSOA01NM     MSOA01CD
# Broxtowe 001 E02005850                   80.0            2.0      31.0
# Broxtowe 002 E02005851                  199.0            4.0      60.0
# Broxtowe 003 E02005852                  106.0            3.0      37.0
# Broxtowe 004 E02005853                  146.0            5.0      62.0
# Broxtowe 007 E02005856                   58.0           17.0      47.0
#
# CRIME_TYPE              Criminal damage and arson  Drugs  Other crime  \
# MSOA01NM     MSOA01CD
# Broxtowe 001 E02005850                       55.0    4.0         12.0
# Broxtowe 002 E02005851                      107.0   13.0         20.0
# Broxtowe 003 E02005852                       35.0    8.0          7.0
# Broxtowe 004 E02005853                       56.0   14.0         16.0
# Broxtowe 007 E02005856                       22.0    5.0          8.0
#
# CRIME_TYPE              Other theft  Possession of weapons  Public order  \
# MSOA01NM     MSOA01CD
# Broxtowe 001 E02005850         39.0                    3.0          15.0
# Broxtowe 002 E02005851         47.0                    6.0          52.0
# Broxtowe 003 E02005852         56.0                    4.0          32.0
# Broxtowe 004 E02005853         37.0                    7.0          33.0
# Broxtowe 007 E02005856         21.0                    3.0          17.0
#
# CRIME_TYPE              Robbery  Shoplifting  Theft from the person  \
# MSOA01NM     MSOA01CD
# Broxtowe 001 E02005850      5.0         99.0                    5.0
# Broxtowe 002 E02005851     10.0        131.0                    9.0
# Broxtowe 003 E02005852      4.0        163.0                    4.0
# Broxtowe 004 E02005853     10.0         66.0                    3.0
# Broxtowe 007 E02005856      2.0          0.0                    4.0
#
# CRIME_TYPE              Vehicle crime  Violence and sexual offences   Total
# MSOA01NM     MSOA01CD
# Broxtowe 001 E02005850           32.0                         115.0   497.0
# Broxtowe 002 E02005851           59.0                         285.0  1002.0
# Broxtowe 003 E02005852           48.0                         102.0   609.0
# Broxtowe 004 E02005853           52.0                         145.0   652.0
# Broxtowe 007 E02005856           30.0                          94.0   328.0

# %% [markdown]
# Copy the MSOA Centroids dataframe and sort by the MSOA code.

# %%
NOTTM_CRIME_MSOA_CENT1 = NOTTM_CRIME_MSOA_CENT
NOTTM_CRIME_MSOA_CENT1.sort_values(by=['MSOA01CD'], inplace=True)
NOTTM_CRIME_MSOA_CENT1.head()
# Out:
#      MSOA01CD  OBJECTID   COUNT       MSOA Name         x          y
# 44  E02002868      2395   631.0  Nottingham 001 -1.175087  53.009121
# 46  E02002869      2397  2035.0  Nottingham 002 -1.198104  53.007202
# 69  E02002871      2462   978.0  Nottingham 004 -1.188205  52.998566
# 67  E02002872      2460  1310.0  Nottingham 005 -1.207894  52.997246
# 68  E02002873      2461   776.0  Nottingham 006 -1.165054  52.995386

# %% [markdown]
# Merge the two dataframes together.  Rename some of the columns for possible furture use.

# %%
NOTTM_CRIME_MSOA_CAT = pd.merge(NOTTM_CRIME_MSOA_CENT1, NOTTM_CRIME_MSOA_CT1, on='MSOA01CD', how='left')
NOTTM_CRIME_MSOA_CAT.drop(['COUNT'], axis=1, inplace=True)
NOTTM_CRIME_MSOA_CAT.rename(columns={'MSOA01CD':'MSOA11CD', 'OBJECTID':'objectid'}, inplace=True)
NOTTM_CRIME_MSOA_CAT#.head()
# Out:
#      MSOA11CD  objectid       MSOA Name         x          y  \
# 0   E02002868      2395  Nottingham 001 -1.175087  53.009121
# 1   E02002869      2397  Nottingham 002 -1.198104  53.007202
# 2   E02002871      2462  Nottingham 004 -1.188205  52.998566
# 3   E02002872      2460  Nottingham 005 -1.207894  52.997246
# 4   E02002873      2461  Nottingham 006 -1.165054  52.995386
# 5   E02002874      2458  Nottingham 007 -1.147781  52.989576
# 6   E02002875      2459  Nottingham 008 -1.176846  52.988949
# 7   E02002876      2456  Nottingham 009 -1.188537  52.983089
# 8   E02002877      2457  Nottingham 010 -1.145603  52.980810
# 9   E02002878      2466  Nottingham 011 -1.212688  52.979902
# 10  E02002879      2469  Nottingham 012 -1.165444  52.978726
# 11  E02002880      2227  Nottingham 013 -1.201766  52.976450
# 12  E02002881      2225  Nottingham 014 -1.226730  52.974496
# 13  E02002882      2223  Nottingham 015 -1.146947  52.971710
# 14  E02002883      2221  Nottingham 016 -1.126056  52.970036
# 15  E02002884      2219  Nottingham 017 -1.161936  52.970348
# 16  E02002885      2217  Nottingham 018 -1.172096  52.966628
# 17  E02002886      2215  Nottingham 019 -1.188240  52.965982
# 18  E02002887      2213  Nottingham 020 -1.212701  52.965511
# 19  E02002888      2231  Nottingham 021 -1.130902  52.962528
# 20  E02002889      2229  Nottingham 022 -1.160553  52.959998
# 51      7.0         75.0                    6.0           33.0
# 52      1.0         11.0                    0.0           54.0
# 53      2.0          5.0                    2.0           27.0
# 54      9.0         14.0                    4.0           60.0
# 55      3.0         10.0                    3.0           58.0
# 56      3.0          9.0                    1.0           19.0
# 57      8.0         42.0                    4.0           57.0
# 58      1.0          0.0                    3.0           27.0
# 59      4.0         58.0                    8.0           37.0
# 60      6.0        139.0                    5.0           78.0
# 61      1.0          8.0                    2.0           45.0
# 62      5.0         38.0                    3.0           76.0
# 63     10.0        129.0                   18.0           57.0
# 64      1.0         17.0                    5.0           77.0
# 65      9.0         71.0                    4.0           91.0
# 66      6.0         13.0                    0.0           48.0
# 67      2.0         10.0                    2.0           38.0
# 68      2.0         27.0                    5.0          105.0
# 69      0.0          1.0                    1.0           29.0
# 70      0.0         29.0                    1.0           26.0
# 71      1.0          0.0                    2.0           28.0
# 72      4.0          5.0                    1.0           51.0
#
#     Violence and sexual offences   Total
# 0                          175.0   631.0
# 1                          489.0  2035.0
# 2                          330.0   978.0
# 3                          426.0  1310.0
# 4                          294.0   776.0
# 5                          437.0  1060.0
# 6                          394.0  1186.0
# 7                          373.0  1260.0
# 8                          197.0   914.0
# 9                          463.0  1254.0
# 10                         286.0  1212.0
# 11                         426.0  1099.0
# 12                         402.0  1197.0
# 13                         337.0  1313.0
# 14                         267.0   715.0
# 15                         293.0  1235.0
# 16                         505.0  2152.0
# 17                         317.0  1093.0
# 18                         226.0   715.0
# 19                         331.0  1144.0
# 20                         713.0  3147.0
# 21                         201.0   729.0
# 22                         263.0   801.0
# 23                         229.0   622.0
# 24                         425.0  1811.0
# 25                          98.0   453.0
# 26                         516.0  1863.0
# 27                          97.0   397.0
# 28                         135.0   734.0
# 29                         177.0   877.0
# ..                           ...     ...
# 43                         152.0   516.0
# 44                         149.0   538.0
# 45                         115.0   426.0
# 46                         118.0   548.0
# 47                         235.0   713.0
# 48                         220.0   618.0
# 49                         136.0   380.0
# 50                         206.0   883.0
# 51                         244.0   882.0
# 52                         121.0   346.0
# 53                          58.0   231.0
# 54                         118.0   506.0
# 55                          99.0   417.0
# 56                         150.0   394.0
# 57                         173.0   561.0
# 58                         133.0   391.0
# 59                         205.0   706.0
# 60                         271.0  1054.0
# 61                         121.0   425.0
# 62                         100.0   517.0
# 63                         198.0  1025.0
# 64                         106.0   564.0
# 65                         124.0   643.0
# 66                         115.0   430.0
# 67                         169.0   520.0
# 68                         116.0   484.0
# 69                          41.0   186.0
# 70                          98.0   280.0
# 71                          98.0   328.0
# 72                         125.0   439.0
#
# [73 rows x 20 columns]

# %% [markdown]
# Now that the we have a breakdown of crimes by MSOA we can veiw that on a map.  First import Folium

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Folium installed and imported!')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                    --> 2020.4.5.1-hecc5488_0     conda-forge
#     certifi:         2020.4.5.1-py36_0             --> 2020.4.5.1-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# ca-certificates-2020 | 146 KB    | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# certifi-2020.4.5.1   | 151 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed and imported!

# %%
# define the world map centered around Nottingham a low zoom level
# Nottingham latitude and longitude values
Nottm_latitude = 52.952
Nottm_longitude = -1.157
Nottm_map = folium.Map(location=[Nottm_latitude, Nottm_longitude], zoom_start=12)
# Nottm_map

# %%
MSOA_Centroids_map = folium.map.FeatureGroup()

# loop through the MSOAs and add each to the incidents feature group
for lat, lng, in zip(NOTTM_CRIME_MSOA_CAT.y, NOTTM_CRIME_MSOA_CAT.x):
    MSOA_Centroids_map.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add pop-up text to each marker on the map
latitudes = list(NOTTM_CRIME_MSOA_CAT.y)
longitudes = list(NOTTM_CRIME_MSOA_CAT.x)
labels = list(NOTTM_CRIME_MSOA_CAT.MSOA11CD)


for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(Nottm_map)    
       
# add MSOA to map    
Nottm_map.add_child(MSOA_Centroids_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Venues in Nottingam 2019 <a name="Venue_Nottm"></a>
#
# Since we now have the Centroids, we can use them to select infoamtion from the Foursquare API.  Foursquare allows the interogation data concerning venues adjacent to a given geigraphic area.  It also provides 'premium' data to collect more infomation regarding the venues, such as ratings, tips and further information.  Given that this analysis is for the general area we will satrt with the non premium service.
#
#
# For the purposes of selection we should use a range of 400 meters around the centroids to look for nearby Venues.  Start off by looking at the Centre of Nottingham, searching for food venues and bars (see https://developer.foursquare.com/docs/build-with-foursquare/categories/)

# %%
CLIENT_ID = '4Y0AAKTDSJHFB2VVIAI3R02XCMRTF0RGWPV1WURZFON1ICGV' # your Foursquare ID
CLIENT_SECRET = '4FGESPJTB5IXJ3YCG5CEAJB0Z0VVDXYBT54KWPM5DUGN52EE' # your Foursquare Secret
VERSION = '20180604'
limit = 100
radius = 400
Nottm_latitude = 52.952
Nottm_longitude = -1.150
Nottm_CatId='4d4b7105d754a06374d81259,4d4b7105d754a06376d81259'
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION,
    Nottm_latitude,
    Nottm_longitude,
    radius,
    limit,
    Nottm_CatId)
#url

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eb9b6b0949393001bf22bc3'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'City Centre',
#   'headerFullLocation': 'City Centre, Nottingham',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'food',
#   'totalResults': 80,
#   'suggestedBounds': {'ne': {'lat': 52.955600003600004,
#     'lng': -1.1440358868855682},
#    'sw': {'lat': 52.94839999639999, 'lng': -1.1559641131144316}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5506c567498ee93a88d9a794',
#        'name': 'Five Guys',
#        'location': {'address': '35 Long Row',
#         'lat': 52.953776733408674,
#         'lng': -1.1502915209188131,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.953776733408674,
#           'lng': -1.1502915209188131}],
#         'distance': 198,
#         'postalCode': 'NG1 2DR',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['35 Long Row',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2DR',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5506c567498ee93a88d9a794-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c4c3caf46240f473d507ff4',
#        'name': 'World Service',
#        'location': {'address': 'Newdigate House',
#         'crossStreet': 'Castle Gate',
#         'lat': 52.95079326205495,
#         'lng': -1.1523121425116496,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95079326205495,
#           'lng': -1.1523121425116496}],
#         'distance': 205,
#         'postalCode': 'NG1 6AF',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Newdigate House (Castle Gate)',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 6AF',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c4c3caf46240f473d507ff4-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56e97a8e498e05403d1ea038',
#        'name': 'Ludorati Café Bar',
#        'location': {'address': '72 Maid Marian Way',
#         'lat': 52.95104957091564,
#         'lng': -1.15206575459735,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95104957091564,
#           'lng': -1.15206575459735}],
#         'distance': 174,
#         'postalCode': 'NG1 6BJ',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['72 Maid Marian Way',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 6BJ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56e97a8e498e05403d1ea038-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5377279f498ea7d99f33b627',
#        'name': 'Delilah',
#        'location': {'address': '12 Victoria St',
#         'lat': 52.95318879437678,
#         'lng': -1.1465456905101634,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95318879437678,
#           'lng': -1.1465456905101634}],
#         'distance': 266,
#         'postalCode': 'NG1 2EX',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['12 Victoria St',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2EX',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5377279f498ea7d99f33b627-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5516c3e3498ea63bf9685c4c',
#        'name': 'Kitty Cafe',
#        'location': {'address': 'Friar Ln',
#         'lat': 52.95205172192822,
#         'lng': -1.1520978431660542,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95205172192822,
#           'lng': -1.1520978431660542}],
#         'distance': 140,
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Friar Ln',
#          'Nottingham',
#          'Nottinghamshire',
#          'United Kingdom']},
#        'categories': [{'id': '56aa371be4b08b9a8d573508',
#          'name': 'Pet Café',
#          'pluralName': 'Pet Cafés',
#          'shortName': 'Pet Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5516c3e3498ea63bf9685c4c-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbf2488f353d13a55167e10',
#        'name': 'Le Mistral',
#        'location': {'address': '2-3 Eldon Chambers',
#         'lat': 52.95230433338245,
#         'lng': -1.1503597383475381,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95230433338245,
#           'lng': -1.1503597383475381}],
#         'distance': 41,
#         'postalCode': 'NG1 2NS',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['2-3 Eldon Chambers',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2NS',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbf2488f353d13a55167e10-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be85805ee96c9283ef9fdbf',
#        'name': 'Memsaab Restaurant',
#        'location': {'address': '12-14 Maid Marian Way',
#         'lat': 52.95279493269992,
#         'lng': -1.1537661763212488,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95279493269992,
#           'lng': -1.1537661763212488}],
#         'distance': 267,
#         'postalCode': 'NG1 6HS',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['12-14 Maid Marian Way',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 6HS',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '350674295'}},
#       'referralId': 'e-0-4be85805ee96c9283ef9fdbf-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5852e6fdbf1a6d72271e70af',
#        'name': 'MOD Pizza',
#        'location': {'lat': 52.95378328356493,
#         'lng': -1.1499649286270142,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95378328356493,
#           'lng': -1.1499649286270142}],
#         'distance': 198,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5852e6fdbf1a6d72271e70af-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55772474498eedcbb44aaffb',
#        'name': 'Baresca',
#        'location': {'lat': 52.952083789325116,
#         'lng': -1.1463103399559675,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.952083789325116,
#           'lng': -1.1463103399559675}],
#         'distance': 247,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55772474498eedcbb44aaffb-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55a24ced498e55f70246782d',
#        'name': 'Fox Cafe',
#        'location': {'address': '9 Pelham Street',
#         'lat': 52.95377,
#         'lng': -1.147148,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95377,
#           'lng': -1.147148}],
#         'distance': 274,
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['9 Pelham Street',
#          'Nottingham',
#          'Nottinghamshire',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55a24ced498e55f70246782d-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5321d371498e48d2059fdcab',
#        'name': 'The Calcutta Club Restaurant',
#        'location': {'address': '8-10 Maid Marian Way',
#         'lat': 52.95288687837999,
#         'lng': -1.153859001965606,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95288687837999,
#           'lng': -1.153859001965606}],
#         'distance': 277,
#         'postalCode': 'NG1 6HS',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['8-10 Maid Marian Way',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 6HS',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5321d371498e48d2059fdcab-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '505f0688e4b05a1bf9443b5e',
#        'name': 'Piccolino',
#        'location': {'address': '7 Weekday Cross',
#         'lat': 52.95156,
#         'lng': -1.146023,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95156,
#           'lng': -1.146023}],
#         'distance': 271,
#         'postalCode': 'NG1 2GB',
#         'cc': 'GB',
#         'neighborhood': 'City Centre',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['7 Weekday Cross',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2GB',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-505f0688e4b05a1bf9443b5e-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc9e8bcfb84c9b668dd1b3e',
#        'name': "Aubrey's Traditional Creperie",
#        'location': {'address': '14-16 Westend Arcade',
#         'crossStreet': 'Long Row',
#         'lat': 52.95426242827112,
#         'lng': -1.1532410721145216,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95426242827112,
#           'lng': -1.1532410721145216}],
#         'distance': 332,
#         'postalCode': 'NG1 6JP',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['14-16 Westend Arcade (Long Row)',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 6JP',
#          'United Kingdom']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f2',
#          'name': 'Creperie',
#          'pluralName': 'Creperies',
#          'shortName': 'Creperie',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/creperie_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc9e8bcfb84c9b668dd1b3e-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54c3d700498e342726c5231b',
#        'name': "Red's True BBQ",
#        'location': {'address': '11 Queen St',
#         'lat': 52.95460439192983,
#         'lng': -1.1500980964248768,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95460439192983,
#           'lng': -1.1500980964248768}],
#         'distance': 289,
#         'postalCode': 'NG1 2BL',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['11 Queen St',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2BL',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54c3d700498e342726c5231b-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '564652ba498e954762aacbfc',
#        'name': 'ZAAP Thai street food',
#        'location': {'address': '6 Bromley Place',
#         'lat': 52.953208845031064,
#         'lng': -1.1538899675700864,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.953208845031064,
#           'lng': -1.1538899675700864}],
#         'distance': 293,
#         'postalCode': 'NG1 6JG',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['6 Bromley Place',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 6JG',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-564652ba498e954762aacbfc-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b546ca5f964a520cfba27e3',
#        'name': 'Pret A Manger',
#        'location': {'address': '10 High Street',
#         'lat': 52.953259840074416,
#         'lng': -1.1475744636222251,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.953259840074416,
#           'lng': -1.1475744636222251}],
#         'distance': 214,
#         'postalCode': 'NG1 2ET',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['10 High Street',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2ET',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b546ca5f964a520cfba27e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5abe2e53364d977ccb4333f8',
#        'name': 'Café Coco Tang',
#        'location': {'lat': 52.951845831374804,
#         'lng': -1.1467000436556702,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.951845831374804,
#           'lng': -1.1467000436556702}],
#         'distance': 221,
#         'postalCode': 'NG1 2GJ',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Nottingham',
#          'Nottinghamshire',
#          'NG1 2GJ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5abe2e53364d977ccb4333f8-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57ad8b35498ea969efa78b05',
#        'name': 'The Speciality Coffee Shop',
#        'location': {'lat': 52.95199,
#         'lng': -1.1524302,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95199,
#           'lng': -1.1524302}],
#         'distance': 162,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57ad8b35498ea969efa78b05-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd9d0003f01c9b6f83753a5',
#        'name': 'Loch Fyne',
#        'location': {'address': '17 King Street',
#         'lat': 52.95467911654253,
#         'lng': -1.1494787703099716,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95467911654253,
#           'lng': -1.1494787703099716}],
#         'distance': 300,
#         'postalCode': 'NG1 2AY',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['17 King Street',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2AY',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd9d0003f01c9b6f83753a5-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9fd8c2f964a520294437e3',
#        'name': 'Yamas Meze & Tapas',
#        'location': {'address': '5 Thurland St.',
#         'lat': 52.954183093061,
#         'lng': -1.1467370121438445,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.954183093061,
#           'lng': -1.1467370121438445}],
#         'distance': 327,
#         'postalCode': 'NG1 3DR',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['5 Thurland St.',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 3DR',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '41335067'}},
#       'referralId': 'e-0-4b9fd8c2f964a520294437e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c28bfcae19720a18f5df858',
#        'name': 'Cumin',
#        'location': {'address': '76 maid marian way',
#         'lat': 52.95129522700912,
#         'lng': -1.1520898699171416,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95129522700912,
#           'lng': -1.1520898699171416}],
#         'distance': 160,
#         'postalCode': 'NG1 6BJ',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['76 maid marian way',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 6BJ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c28bfcae19720a18f5df858-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a9d3c818a6f1737281851c1',
#        'name': 'Doughnotts',
#        'location': {'address': '25 Long Row',
#         'lat': 52.95385,
#         'lng': -1.14966,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95385,
#           'lng': -1.14966}],
#         'distance': 207,
#         'postalCode': 'NG1 2DR',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['25 Long Row',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2DR',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'shortName': 'Donuts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a9d3c818a6f1737281851c1-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '546e6b43498e3b3bd9153fbf',
#        'name': "Oscar & Rosie's",
#        'location': {'lat': 52.952132,
#         'lng': -1.145817,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.952132,
#           'lng': -1.145817}],
#         'distance': 280,
#         'cc': 'GB',
#         'neighborhood': 'City Centre',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-546e6b43498e3b3bd9153fbf-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51b08fed498ef66fd277a0ab',
#        'name': 'Barburrito',
#        'location': {'address': '22 King St',
#         'lat': 52.95469924411631,
#         'lng': -1.1494634992338173,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95469924411631,
#           'lng': -1.1494634992338173}],
#         'distance': 302,
#         'postalCode': 'NG1 2AS',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['22 King St',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2AS',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d153941735',
#          'name': 'Burrito Place',
#          'pluralName': 'Burrito Places',
#          'shortName': 'Burritos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51b08fed498ef66fd277a0ab-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2f1afe452620a101ef1c0f',
#        'name': 'Fothergills',
#        'location': {'lat': 52.95064139626782,
#         'lng': -1.153260644580335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95064139626782,
#           'lng': -1.153260644580335}],
#         'distance': 265,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'shortName': 'Gastropub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2f1afe452620a101ef1c0f-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb2342214cfd13a6d9d14ab',
#        'name': 'Chino Latino',
#        'location': {'address': '41 Maid Marian Way',
#         'lat': 52.95275703337335,
#         'lng': -1.153624411585142,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95275703337335,
#           'lng': -1.153624411585142}],
#         'distance': 257,
#         'postalCode': 'NG1 6GD',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['41 Maid Marian Way',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 6GD',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '403439353'}},
#       'referralId': 'e-0-4bb2342214cfd13a6d9d14ab-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54821c7c498e8f59cdfe6daf',
#        'name': "George's Great British Kitchen",
#        'location': {'address': '13 Queen St',
#         'lat': 52.95428517292031,
#         'lng': -1.1497142364153854,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95428517292031,
#           'lng': -1.1497142364153854}],
#         'distance': 255,
#         'postalCode': 'NG1 2BL',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['13 Queen St',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2BL',
#          'United Kingdom']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a05',
#          'name': 'English Restaurant',
#          'pluralName': 'English Restaurants',
#          'shortName': 'English',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54821c7c498e8f59cdfe6daf-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fb82194e4b088e27d4ee671',
#        'name': 'Roosters Piri Piri',
#        'location': {'address': '4-5 Angel Row',
#         'lat': 52.95390475502788,
#         'lng': -1.1528693495763307,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95390475502788,
#           'lng': -1.1528693495763307}],
#         'distance': 286,
#         'postalCode': 'NG1 6HL',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['4-5 Angel Row',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 6HL',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fb82194e4b088e27d4ee671-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b563bf5f964a520aa0628e3',
#        'name': 'Iberico World Tapas',
#        'location': {'address': 'The Shire Hall, High Pavement',
#         'lat': 52.950847599047414,
#         'lng': -1.1443817810592813,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.950847599047414,
#           'lng': -1.1443817810592813}],
#         'distance': 398,
#         'postalCode': 'NG1 1HN',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['The Shire Hall, High Pavement',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 1HN',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b563bf5f964a520aa0628e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9d02a8f964a520608836e3',
#        'name': 'Homemade',
#        'location': {'address': '20 Pelham St.',
#         'lat': 52.95373819921773,
#         'lng': -1.146565272788132,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95373819921773,
#           'lng': -1.146565272788132}],
#         'distance': 300,
#         'postalCode': 'NG1 2EG',
#         'cc': 'GB',
#         'neighborhood': 'City Centre',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['20 Pelham St.',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2EG',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9d02a8f964a520608836e3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '502b92f8e4b0b81736dca949',
#        'name': 'Patisserie Valerie',
#        'location': {'address': 'Unit 3, Exchange Arcade',
#         'lat': 52.95359769439032,
#         'lng': -1.1487531812351681,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95359769439032,
#           'lng': -1.1487531812351681}],
#         'distance': 196,
#         'postalCode': 'NG1 2DD',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Unit 3, Exchange Arcade',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2DD',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-502b92f8e4b0b81736dca949-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '567a2a96498e169236c70302',
#        'name': 'Taco Bell',
#        'location': {'address': 'Angel Row',
#         'lat': 52.95380438357256,
#         'lng': -1.152550938575118,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95380438357256,
#           'lng': -1.152550938575118}],
#         'distance': 263,
#         'postalCode': 'NG1 6HL',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Angel Row',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 6HL',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-567a2a96498e169236c70302-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba213aff964a52023da37e3',
#        'name': 'CookieShake',
#        'location': {'address': 'Upper Parliament St',
#         'lat': 52.95520299403456,
#         'lng': -1.1484880776637487,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95520299403456,
#           'lng': -1.1484880776637487}],
#         'distance': 370,
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Upper Parliament St',
#          'Nottingham',
#          'Nottinghamshire',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba213aff964a52023da37e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd7591ce914a5933c0751fa',
#        'name': 'Laguna tandoori',
#        'location': {'address': 'Mount street',
#         'lat': 52.952817235937175,
#         'lng': -1.1544139199747305,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.952817235937175,
#           'lng': -1.1544139199747305}],
#         'distance': 309,
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Mount street',
#          'Nottingham',
#          'Nottinghamshire',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd7591ce914a5933c0751fa-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56276abf498e456ac81b4af9',
#        'name': 'Copper',
#        'location': {'lat': 52.954915430082295,
#         'lng': -1.1515133648439642,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.954915430082295,
#           'lng': -1.1515133648439642}],
#         'distance': 340,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56276abf498e456ac81b4af9-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e71e4b6d22dbd62616bf931',
#        'name': "Man's Restaurant 文轩",
#        'location': {'address': 'Unit B4, Chapel Bar',
#         'crossStreet': 'Mount St.',
#         'lat': 52.953627258226405,
#         'lng': -1.1538644965582583,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.953627258226405,
#           'lng': -1.1538644965582583}],
#         'distance': 316,
#         'postalCode': 'NG1 6JQ',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Unit B4, Chapel Bar (Mount St.)',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 6JQ',
#          'United Kingdom']},
#        'categories': [{'id': '52af3a7c3cf9994f4e043bed',
#          'name': 'Cantonese Restaurant',
#          'pluralName': 'Cantonese Restaurants',
#          'shortName': 'Cantonese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e71e4b6d22dbd62616bf931-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53c69533498ec1630dcd70c3',
#        'name': "Bill's Restaurant",
#        'location': {'address': '15 Queen St',
#         'lat': 52.95417496738407,
#         'lng': -1.1496042155806083,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95417496738407,
#           'lng': -1.1496042155806083}],
#         'distance': 243,
#         'postalCode': 'NG1 2BL',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['15 Queen St',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2BL',
#          'United Kingdom']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a05',
#          'name': 'English Restaurant',
#          'pluralName': 'English Restaurants',
#          'shortName': 'English',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53c69533498ec1630dcd70c3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f7f4783e4b04310244a996e',
#        'name': 'Curry Lounge',
#        'location': {'address': '110 Upper Parliament St. Nottingham',
#         'lat': 52.954616542406036,
#         'lng': -1.1535560481046672,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.954616542406036,
#           'lng': -1.1535560481046672}],
#         'distance': 376,
#         'postalCode': 'NG1 6LF',
#         'cc': 'GB',
#         'city': 'Nottinghamshire',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['110 Upper Parliament St. Nottingham',
#          'Nottinghamshire',
#          'NG1 6LF',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f7f4783e4b04310244a996e-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '561950dd498e8f2d1f044cb2',
#        'name': 'Oaks',
#        'location': {'address': 'Bromley Place',
#         'lat': 52.953085,
#         'lng': -1.153701,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.953085,
#           'lng': -1.153701}],
#         'distance': 276,
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Bromley Place',
#          'Nottingham',
#          'Nottinghamshire',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-561950dd498e8f2d1f044cb2-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53fb31f9498eacb60d7c52bb',
#        'name': 'Wildwood Kitchen',
#        'location': {'address': '18 King St',
#         'lat': 52.954602749409695,
#         'lng': -1.14944644914082,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.954602749409695,
#           'lng': -1.14944644914082}],
#         'distance': 292,
#         'postalCode': 'NG1 2AS',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['18 King St',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2AS',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
# ...
#         'lng': -1.1493576,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.9546184,
#           'lng': -1.1493576}],
#         'distance': 294,
#         'postalCode': 'NG1 2AS',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['20 King Street',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2AS',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bacfdc1f964a52005223be3-66'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d39e702bf6d5481dfd6c7e1',
#        'name': 'Petit Paris',
#        'location': {'address': '2 Kings Walk',
#         'lat': 52.95510089229384,
#         'lng': -1.1493658133777764,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95510089229384,
#           'lng': -1.1493658133777764}],
#         'distance': 347,
#         'postalCode': 'NG1 2AE',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['2 Kings Walk',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2AE',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d39e702bf6d5481dfd6c7e1-67'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba21beff964a52052dc37e3',
#        'name': 'Prezzo',
#        'location': {'address': '21-23 Forman St',
#         'lat': 52.95542567042667,
#         'lng': -1.1499023544203857,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95542567042667,
#           'lng': -1.1499023544203857}],
#         'distance': 381,
#         'postalCode': 'NG1 4AA',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['21-23 Forman St',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 4AA',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba21beff964a52052dc37e3-68'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4babd1f7f964a52086cc3ae3',
#        'name': 'Bella Italia',
#        'location': {'address': 'G4-6 Corner House Forman Street',
#         'crossStreet': 'Forman St',
#         'lat': 52.9555188,
#         'lng': -1.1502447,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.9555188,
#           'lng': -1.1502447}],
#         'distance': 392,
#         'postalCode': 'NG1 4DB',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['G4-6 Corner House Forman Street (Forman St)',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 4DB',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4babd1f7f964a52086cc3ae3-69'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5cd88ae631ac6c002cdc5751',
#        'name': 'The B Sweet',
#        'location': {'address': 'Wheeler Street',
#         'lat': 52.952703,
#         'lng': -1.150403,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.952703,
#           'lng': -1.150403}],
#         'distance': 82,
#         'postalCode': 'NG1 2NA',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Wheeler Street',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2NA',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5cd88ae631ac6c002cdc5751-70'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '561e368c498e151d8c2842e1',
#        'name': 'Time Out Cafe and Kitchen',
#        'location': {'address': '14-16 Wheeler Gate',
#         'lat': 52.952647,
#         'lng': -1.150149,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.952647,
#           'lng': -1.150149}],
#         'distance': 72,
#         'postalCode': 'NG1 2NB',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['14-16 Wheeler Gate',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2NB',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-561e368c498e151d8c2842e1-71'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a2fa4e60c9f315312cea18b',
#        'name': 'Ugly Bread Bakery',
#        'location': {'address': '21 market street',
#         'lat': 52.95458962065259,
#         'lng': -1.1514562368392944,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95458962065259,
#           'lng': -1.1514562368392944}],
#         'distance': 304,
#         'postalCode': 'NG1 6HX',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['21 market street',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 6HX',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a2fa4e60c9f315312cea18b-72'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54da67e7498ea6b7525b655f',
#        'name': 'Manga Sushi',
#        'location': {'address': '21 King Street',
#         'lat': 52.954814,
#         'lng': -1.149363,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.954814,
#           'lng': -1.149363}],
#         'distance': 316,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['21 King Street', 'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54da67e7498ea6b7525b655f-73'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50f19edde4b0f8af1b495c9d',
#        'name': "Singh's",
#        'location': {'address': '30 Market St',
#         'lat': 52.95477956280377,
#         'lng': -1.1514322944589452,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95477956280377,
#           'lng': -1.1514322944589452}],
#         'distance': 323,
#         'postalCode': 'NG1 6HW',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['30 Market St',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 6HW',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50f19edde4b0f8af1b495c9d-74'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56705e85498ef66409364f8b',
#        'name': 'Steak Lounge',
#        'location': {'lat': 52.954785,
#         'lng': -1.152747,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.954785,
#           'lng': -1.152747}],
#         'distance': 360,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '52e81612bcbc57f1066b79ff',
#          'name': 'Halal Restaurant',
#          'pluralName': 'Halal Restaurants',
#          'shortName': 'Halal',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56705e85498ef66409364f8b-75'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a9bde7ba9fe1261ec04ca03',
#        'name': 'Sushi Mania',
#        'location': {'lat': 52.954245,
#         'lng': -1.154132,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.954245,
#           'lng': -1.154132}],
#         'distance': 373,
#         'postalCode': 'NG1',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Nottingham',
#          'Nottinghamshire',
#          'NG1',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a9bde7ba9fe1261ec04ca03-76'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51c9838a498e33aa3b75bdc5',
#        'name': 'Cosmo Nottingham',
#        'location': {'address': '29A Milton Street',
#         'lat': 52.95535364731739,
#         'lng': -1.150030521343735,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95535364731739,
#           'lng': -1.150030521343735}],
#         'distance': 373,
#         'postalCode': 'NG1 3EN',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['29A Milton Street',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 3EN',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '406188745'}},
#       'referralId': 'e-0-51c9838a498e33aa3b75bdc5-77'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51349f27e4b0eacbd67f7931',
#        'name': 'peri peri chicken',
#        'location': {'lat': 52.95541122938961,
#         'lng': -1.1508549039231466,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95541122938961,
#           'lng': -1.1508549039231466}],
#         'distance': 384,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51349f27e4b0eacbd67f7931-78'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc5913069369521ff338488',
#        'name': 'Greggs',
#        'location': {'address': '25 Upper Parliament St',
#         'lat': 52.95546848132878,
#         'lng': -1.1499745957241367,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.95546848132878,
#           'lng': -1.1499745957241367}],
#         'distance': 386,
#         'postalCode': 'NG1 2AP',
#         'cc': 'GB',
#         'city': 'Nottingham',
#         'state': 'Nottinghamshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['25 Upper Parliament St',
#          'Nottingham',
#          'Nottinghamshire',
#          'NG1 2AP',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc5913069369521ff338488-79'}]}]}}

# %% [markdown]
# Now we are ready to clean the json and structure it into a *pandas* dataframe.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
Nottm_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
Nottm_venues =Nottm_venues.loc[:, filtered_columns]

# filter the category for each row
Nottm_venues['venue.categories'] = Nottm_venues.apply(get_category_type, axis=1)

# clean columns
Nottm_venues.columns = [col.split(".")[-1] for col in Nottm_venues.columns]

Nottm_venues.head()
# Out:
#                 name     categories        lat       lng
# 0          Five Guys   Burger Joint  52.953777 -1.150292
# 1      World Service     Restaurant  52.950793 -1.152312
# 2  Ludorati Café Bar           Café  52.951050 -1.152066
# 3            Delilah  Deli / Bodega  52.953189 -1.146546
# 4         Kitty Cafe       Pet Café  52.952052 -1.152098

# %% [markdown]
# Now Explore the MSOAs in the Nottingham Urban Area. Define a function for determine the nearby venues for MSOAs recorded in NOTTM_CRIME_MSOA_CAT.

# %%
def getNottmVenues(names, latitudes, longitudes, radius=400):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            limit,
            Nottm_CatId)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    Nottm_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    Nottm_venues.columns = ['MSOA Name', 
                  'MSOA_Latitude', 
                  'MSOA_Longitude', 
                  'Venue', 
                  'Venue_Latitude', 
                  'Venue_Longitude', 
                  'Venue_Category']
    return(Nottm_venues)

# %%
Nottm_venues = getNottmVenues(names=NOTTM_CRIME_MSOA_CAT['MSOA Name'],
                                   latitudes=NOTTM_CRIME_MSOA_CAT['y'],
                                   longitudes=NOTTM_CRIME_MSOA_CAT['x']
                                  )
# Out:
# Nottingham 001
# Nottingham 002
# Nottingham 004
# Nottingham 005
# Nottingham 006
# Nottingham 007
# Nottingham 008
# Nottingham 009
# Nottingham 010
# Nottingham 011
# Nottingham 012
# Nottingham 013
# Nottingham 014
# Nottingham 015
# Nottingham 016
# Nottingham 017
# Nottingham 018
# Nottingham 019
# Nottingham 020
# Nottingham 021
# Nottingham 022
# Nottingham 023
# Nottingham 024
# Nottingham 025
# Nottingham 026
# Nottingham 027
# Nottingham 029
# Nottingham 030
# Nottingham 031
# Nottingham 032
# Nottingham 034
# Nottingham 035
# Nottingham 036
# Nottingham 037
# Broxtowe 001
# Broxtowe 002
# Broxtowe 003
# Broxtowe 004
# Broxtowe 007
# Broxtowe 008
# Broxtowe 009
# Broxtowe 010
# Broxtowe 011
# Broxtowe 012
# Broxtowe 013
# Broxtowe 014
# Broxtowe 015
# Gedling 001
# Gedling 002
# Gedling 004
# Gedling 005
# Gedling 006
# Gedling 007
# Gedling 008
# Gedling 009
# Gedling 010
# Gedling 011
# Gedling 012
# Gedling 013
# Gedling 014
# Gedling 015
# Rushcliffe 003
# Rushcliffe 004
# Rushcliffe 005
# Rushcliffe 006
# Rushcliffe 007
# Rushcliffe 008
# Rushcliffe 009
# Rushcliffe 011
# Rushcliffe 012
# Rushcliffe 013
# Rushcliffe 014
# Rushcliffe 015

# %%
Nottm_venues.head()
# Out:
#         MSOA Name  MSOA_Latitude  MSOA_Longitude  \
# 0  Nottingham 001      53.009121       -1.175087
# 1  Nottingham 001      53.009121       -1.175087
# 2  Nottingham 001      53.009121       -1.175087
# 3  Nottingham 004      52.998566       -1.188205
# 4  Nottingham 004      52.998566       -1.188205
#
#                                   Venue  Venue_Latitude  Venue_Longitude  \
# 0            Smith’s Coffee Shop & Cafe       53.010254        -1.173920
# 1  Winnies  coffee shop and cafe lounge       53.010106        -1.173332
# 2                     Sea King Fish Bar       53.010079        -1.173404
# 3                       Apollo Fish Bar       52.996991        -1.192789
# 4                     Highbury Fish Bar       52.995534        -1.191196
#
#          Venue_Category
# 0                  Café
# 1                  Café
# 2     Fish & Chips Shop
# 3  Fast Food Restaurant
# 4     Fish & Chips Shop

# %%
Nottm_venues.shape
# Out:
# (159, 7)

# %% [markdown]
# Reveiw the data on a Map

# %%
# create map of Nottingham using latitude and longitude values of Venues Nearby to MSOA
Ven_Map_Nottingham = folium.Map(location=[Nottm_latitude, Nottm_longitude], zoom_start=13)

# add markers to map
for lat, lng, label in zip(Nottm_venues['Venue_Latitude'], Nottm_venues['Venue_Longitude'], Nottm_venues['Venue']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='Red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Ven_Map_Nottingham)  
    
Ven_Map_Nottingham
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## LSOA Revisited <a name="LSOA"></a>
#
# Closer examination of the map will show that there a very few entries for the centre of Nottingham.  Looking back to the MSOA Centroids map we can note that the we can also see that there are no MSOA Centroids based in the centre of the city and so this means that the search for nearby venues may not have found results for the city centre.  Indeed, if we examine the inital result for the Foursqaure search for the venter of Nottingham, the venues found in that search were not returned for the MSOA search.  This may partially be explained due to the fact that the MSOA centroids provided by the ONS are weighted by population.  The population information is sourced from Census data and reflects the fact that no mayy people live in the Centre of the City, compared tot he suburbs.  At this point it is appropriate to reveiw the approact to finding the point to reveiw the information in order to get better coverage of Nottingham.  Going back to original crime detials held in NOTTM_CRIMEdf we can  see that each crime has an anonimised latitude and longitude associated with it.  It should therefor be possible to generate a crime weighted centroid for an LSOA (or indeed the linked MSOA) by finding the average of latitude and longitde for all crimes commited in the LSOA (MSOA).  Attempt to work this through for an LSOA - this will provide more detial coverage of the city.

# %%
#  Reveiw the dataframe 
NOTTM_CRIMEdf.head()
# Out:
#      MONTH             REPORTED_BY  LONGITUDE   LATITUDE  \
# 0  2019-01  Nottinghamshire Police  -1.320816  53.032832
# 1  2019-01  Nottinghamshire Police  -1.312767  53.043870
# 2  2019-01  Nottinghamshire Police  -1.309872  53.040248
# 3  2019-01  Nottinghamshire Police  -1.309787  53.032463
# 4  2019-01  Nottinghamshire Police  -1.317157  53.044533
#
#                             LOCATION  LSOA_CODE      LSOA_NAME  \
# 0             On or near Stoney Lane  E01028092  Broxtowe 001A
# 1              On or near Broad Lane  E01028092  Broxtowe 001A
# 2  On or near Sports/Recreation Area  E01028092  Broxtowe 001A
# 3          On or near Mansfield Road  E01028092  Broxtowe 001A
# 4         On or near Whitehead Drive  E01028093  Broxtowe 001B
#
#                      CRIME_TYPE  \
# 0     Criminal damage and arson
# 1                  Public order
# 2  Violence and sexual offences
# 3  Violence and sexual offences
# 4                 Vehicle crime
#
#                            LAST_OUTCOME_CATEGORY CONTEXT
# 0  Investigation complete; no suspect identified    None
# 1                    Unable to prosecute suspect    None
# 2  Investigation complete; no suspect identified    None
# 3  Investigation complete; no suspect identified    None
# 4  Investigation complete; no suspect identified    None

# %% [markdown]
# So lets reconnect to DB2 and run some more SQL

# %%
try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  BLUDB as user:  ctz66893 on host:  dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net

# %%
#connection for pandas
pconn = ibm_db_dbi.Connection(conn)

#query statement to retrieve all rows in in the Crime Table, with the MSOA code and object type assigned
selectQuery = "select LSOA_NAME, count(*) as COUNT, AVG(LONGITUDE) as LONGITUDE,  AVG(LATITUDE) as LATITUDE from NOTTINGHAM_CRIME_2019 group by LSOA_NAME"


#retrieve the query results into a pandas dataframe
NOTTM_LSOA_CC = pd.read_sql(selectQuery, pconn)

#print just the LNAME for first row in the pandas data frame
NOTTM_LSOA_CC.head()
# Out:
#        LSOA_NAME  COUNT  LONGITUDE   LATITUDE
# 0  Broxtowe 001A   67.0  -1.314053  53.037770
# 1  Broxtowe 001B   42.0  -1.314539  53.042886
# 2  Broxtowe 001C  149.0  -1.304791  53.021653
# 3  Broxtowe 001D   70.0  -1.298100  53.021100
# 4  Broxtowe 001E  169.0  -1.294581  53.015193

# %% [markdown]
# We can also pull the same tyep of information for the MSOA.

# %%
#query statement to retrieve all rows in in the Crime Table, with the MSOA code and object type assigned
selectQuery = "select MS.MSOA01NM, count(*) as COUNT, avg(NC.LONGITUDE) as LONGITUDE, AVG(NC.LATITUDE) as LATITUDE \
from NOTTINGHAM_CRIME_2019 as NC join MSOA_LINK as MS on NC.LSOA_CODE = MS.LSOA01CD \
group by MS.MSOA01NM"
#retrieve the query results into a pandas dataframe
NOTTM_MSOA_CC = pd.read_sql(selectQuery, pconn)

#print just the LNAME for first row in the pandas data frame
NOTTM_MSOA_CC.head()
# Out:
#        MSOA01NM   COUNT  LONGITUDE   LATITUDE
# 0  Broxtowe 001   497.0  -1.302449  53.023346
# 1  Broxtowe 002  1002.0  -1.306782  53.015598
# 2  Broxtowe 003   609.0  -1.285894  53.007876
# 3  Broxtowe 004   652.0  -1.252607  52.999937
# 4  Broxtowe 005   252.0  -1.271513  52.992906

# %%
# create map of Nottingham using latitude and longitude values
LCr_Map_Nottingham = folium.Map(location=[Nottm_latitude, Nottm_longitude], zoom_start=13)

# add markers to map
for lat, lng, label in zip(NOTTM_LSOA_CC['LATITUDE'], NOTTM_LSOA_CC['LONGITUDE'], NOTTM_LSOA_CC['LSOA_NAME']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='Red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(LCr_Map_Nottingham)
    
for lat, lng, label in zip(NOTTM_MSOA_CC['LATITUDE'], NOTTM_MSOA_CC['LONGITUDE'], NOTTM_MSOA_CC['MSOA01NM']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=7,
        popup=label,
        color='Blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(LCr_Map_Nottingham) 
    
LCr_Map_Nottingham
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# In the above map the Blue dots are the MSOAs, the blue dots the LSOAs - both wirghted for crime.  From this it would appear that the use of Crime Weighted LSOAs gives better coverage accross Nottingham and includes the city centre. We can elect to use the LSOAs going forward.

# %%
ibm_db.close(conn)   #  so hopefully that shoud be that
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-80-625a126792fe> in <module>
# ----> 1 ibm_db.close(conn)   #  so hopefully that shoud be that
#
# Exception: Connection is not active

# %% [markdown]
# Re- run the function to get the nearby velues with the LSOA data - set the range to 200 meters since the cenroids are closer together.

# %%
Nottm_venues
# Out:
#           MSOA Name  MSOA_Latitude  MSOA_Longitude  \
# 0    Nottingham 001      53.009121       -1.175087
# 1    Nottingham 001      53.009121       -1.175087
# 2    Nottingham 001      53.009121       -1.175087
# 3    Nottingham 004      52.998566       -1.188205
# 4    Nottingham 004      52.998566       -1.188205
# 5    Nottingham 006      52.995386       -1.165054
# 6    Nottingham 009      52.983089       -1.188537
# 7    Nottingham 010      52.980810       -1.145603
# 8    Nottingham 010      52.980810       -1.145603
# 9    Nottingham 010      52.980810       -1.145603
# 10   Nottingham 010      52.980810       -1.145603
# 11   Nottingham 010      52.980810       -1.145603
# 12   Nottingham 010      52.980810       -1.145603
# 13   Nottingham 010      52.980810       -1.145603
# 14   Nottingham 011      52.979902       -1.212688
# 15   Nottingham 012      52.978726       -1.165444
# 16   Nottingham 012      52.978726       -1.165444
# 17   Nottingham 012      52.978726       -1.165444
# 18   Nottingham 012      52.978726       -1.165444
# 19   Nottingham 013      52.976450       -1.201766
# 20   Nottingham 015      52.971710       -1.146947
# 21   Nottingham 015      52.971710       -1.146947
# 22   Nottingham 015      52.971710       -1.146947
# 23   Nottingham 015      52.971710       -1.146947
# 24   Nottingham 015      52.971710       -1.146947
# 25   Nottingham 015      52.971710       -1.146947
# 26   Nottingham 017      52.970348       -1.161936
# 27   Nottingham 018      52.966628       -1.172096
# 28   Nottingham 018      52.966628       -1.172096
# 29   Nottingham 018      52.966628       -1.172096
# ..              ...            ...             ...
# 129     Gedling 015      52.962155       -1.077687
# 130     Gedling 015      52.962155       -1.077687
# 131  Rushcliffe 004      52.935143       -1.120223
# 132  Rushcliffe 004      52.935143       -1.120223
# 144                         Cotgrave Fish Bar       52.910487
# 145                        The Hot Bread Shop       52.910551
# 146                      Philo's Delicatessen       52.892328
# 147                       Ruddington Fish Bar       52.892565
# 148                              Three Spices       52.893199
# 149                      Mathew's Café & Deli       52.891396
# 150                             Indian Nights       52.871902
# 151                             Mario's Pizza       52.874084
# 152                        The Hot Bread Shop       52.874333
# 153                         Burns Coffee Shop       52.871323
# 154                 The Village Cafe & Bistro       52.870568
# 155                     Plumtree Fish & Chips       52.876810
# 156                                   Bryer's       52.832050
# 157                                      Heat       52.831732
# 158                               Chef's Café       52.831661
#
#      Venue_Longitude                 Venue_Category
# 0          -1.173920                           Café
# 1          -1.173332                           Café
# 2          -1.173404              Fish & Chips Shop
# 3          -1.192789           Fast Food Restaurant
# 4          -1.191196              Fish & Chips Shop
# 5          -1.168491              Indian Restaurant
# 6          -1.186810           Fast Food Restaurant
# 7          -1.146122       Mediterranean Restaurant
# 8          -1.145782            Japanese Restaurant
# 9          -1.144951                 Breakfast Spot
# 10         -1.145926             Italian Restaurant
# 11         -1.146030                           Café
# 12         -1.146398    Eastern European Restaurant
# 13         -1.144963                         Bakery
# 14         -1.208423                         Bakery
# 15         -1.168461                     Restaurant
# 16         -1.168750                     Steakhouse
# 17         -1.169388                     Restaurant
# 18         -1.168107           Fast Food Restaurant
# 19         -1.203969                           Café
# 20         -1.144307  Vegetarian / Vegan Restaurant
# 21         -1.149054             Chinese Restaurant
# 22         -1.151931                           Café
# 23         -1.152041           Fast Food Restaurant
# 24         -1.152548                         Bakery
# 25         -1.141817             Chinese Restaurant
# 26         -1.157425                           Café
# 27         -1.169980      Middle Eastern Restaurant
# 28         -1.172266           Fast Food Restaurant
# 29         -1.171496                           Café
# ..               ...                            ...
# 129        -1.079820                 Breakfast Spot
# 130        -1.078626                           Café
# 131        -1.118991              Fish & Chips Shop
# 132        -1.119254             English Restaurant
# 133        -1.120029                    Pizza Place
# 134        -1.128583                 Breakfast Spot
# 135        -1.129030           Fast Food Restaurant
# 136        -1.130523              Fish & Chips Shop
# 137        -1.130003              Indian Restaurant
# 138        -1.128588                  Deli / Bodega
# 139        -1.110760                     Restaurant
# 140        -1.153218                    Pizza Place
# 141        -1.152485              Indian Restaurant
# 142        -1.152781             Turkish Restaurant
# 143        -1.152898                      Gastropub
# 144        -1.037184              Fish & Chips Shop
# 145        -1.037823                         Bakery
# 146        -1.149563                  Deli / Bodega
# 147        -1.149553              Fish & Chips Shop
# 148        -1.147368                     Restaurant
# 149        -1.149359                           Café
# 150        -1.090264              Indian Restaurant
# 151        -1.082754                    Pizza Place
# 152        -1.082677                         Bakery
# 153        -1.091107                           Café
# 154        -1.089262                           Café
# 155        -1.089298              Fish & Chips Shop
# 156        -1.177597                  Deli / Bodega
# 157        -1.177458              Indian Restaurant
# 158        -1.177437                           Café
#
# [159 rows x 7 columns]

# %%
def getNottmVenues(names, latitudes, longitudes, radius=200):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            limit,
            Nottm_CatId)
        
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'],
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    Nottm_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
# Sandwell 013E
# Sandwell 034F

# %%
Nottm_venues.head()
# Out:
#        LSOA_Name  LSOA_Latitude  LSOA_Longitude               Venue  \
# 0  Broxtowe 001D      53.021100       -1.298100       Hilltop Pizza
# 1  Broxtowe 001E      53.015193       -1.294581  Pizza Hut Delivery
# 2  Broxtowe 001E      53.015193       -1.294581      The Olive Tree
# 3  Broxtowe 001E      53.015193       -1.294581        Jade Kitchen
# 4  Broxtowe 002C      53.017924       -1.304420              Greggs
#
#    Venue_Latitude  Venue_Longitude      Venue_Category
# 0       53.020157        -1.296591         Pizza Place
# 1       53.014380        -1.294511         Pizza Place
# 2       53.014432        -1.294398    Kebab Restaurant
# 3       53.014484        -1.294160  Chinese Restaurant
# 4       53.017824        -1.304440              Bakery

# %%
Nottm_venues.shape
# Out:
# (426, 7)

# %% [markdown]
# Again - reveiw this on a map.  Resaurants in yellow, LSOAs in red.

# %%
# create map of Nottingham using latitude and longitude values
LCr_Map_Nottingham = folium.Map(location=[Nottm_latitude, Nottm_longitude], zoom_start=13)

# add markers for LSOA to map
for lat, lng, label in zip(NOTTM_LSOA_CC['LATITUDE'], NOTTM_LSOA_CC['LONGITUDE'], NOTTM_LSOA_CC['LSOA_NAME']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='Red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(LCr_Map_Nottingham)
    
for lat, lng, label in zip(Nottm_venues['Venue_Latitude'], Nottm_venues['Venue_Longitude'], Nottm_venues['Venue']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='Yellow',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(LCr_Map_Nottingham) 
    
LCr_Map_Nottingham
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print('There are {} unique categories.'.format(len(Nottm_venues['Venue_Category'].unique())))

Nottm_cats = Nottm_venues['Venue_Category'].unique()
Nottm_cats
# Out:
# There are 58 unique categories.
# array(['Pizza Place', 'Kebab Restaurant', 'Chinese Restaurant', 'Bakery',
#        'Indian Restaurant', 'Italian Restaurant', 'Fish & Chips Shop',
#        'Café', 'Fast Food Restaurant', 'Scandinavian Restaurant',
#        'Sandwich Place', 'American Restaurant', 'Portuguese Restaurant',
#        'Breakfast Spot', 'Korean Restaurant', 'Thai Restaurant',
#        'Cafeteria', 'Theme Restaurant', 'Falafel Restaurant',
#        'Deli / Bodega', 'Burger Joint', 'BBQ Joint', 'Restaurant', 'Food',
#        'Steakhouse', 'Greek Restaurant', 'Snack Place',
#        'Cuban Restaurant', 'Mediterranean Restaurant',
#        'Japanese Restaurant', 'Eastern European Restaurant',
#        'Lebanese Restaurant', 'Asian Restaurant',
#        'Vegetarian / Vegan Restaurant', 'Middle Eastern Restaurant',
#        'Fried Chicken Joint', 'Food Court', 'Donut Shop', 'Burrito Place',
#        'Dim Sum Restaurant', 'Szechuan Restaurant', 'French Restaurant',
#        'Caribbean Restaurant', 'Buffet', 'Sushi Restaurant',
#        'Noodle House', 'Diner', 'Gastropub', 'English Restaurant',
#        'Halal Restaurant', 'Mexican Restaurant', 'Pet Café',
#        'Tapas Restaurant', 'Belgian Restaurant', 'Seafood Restaurant',
#        'Wings Joint', 'Cantonese Restaurant', 'Turkish Restaurant'],
#       dtype=object)

# %% [markdown]
# Now the restaurants in Nottingham city centre and its surrounding Urban environment are available - we have a list of venues and associated LSOAs that we can now carry out some analysis on.
